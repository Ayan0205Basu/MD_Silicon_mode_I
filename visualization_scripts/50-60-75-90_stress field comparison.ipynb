# %%
import matplotlib as mpl
mpl.rcParams['font.family']='serif'
mpl.rcParams['mathtext.fontset']='cm'
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from matplotlib.pyplot import legend,gca
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes
from mpl_toolkits.axes_grid1.inset_locator import mark_inset

# %%
dt = pd.read_excel (r'nd_0.50.xlsx')
mat = dt.to_numpy()
new_mat=np.transpose(mat)
p_50=new_mat[1]
s_50=new_mat[2]
pn_50=new_mat[3]
sn_50=new_mat[4]

# %%
dt = pd.read_excel (r'nd_0.60.xlsx')
mat = dt.to_numpy()
new_mat=np.transpose(mat)
p_60=new_mat[1]
s_60=new_mat[2]
pn_60=new_mat[3]
sn_60=new_mat[4]

# %%
dt = pd.read_excel (r'nd_0.85.xlsx')
mat = dt.to_numpy()
new_mat=np.transpose(mat)
p_85=new_mat[1]
s_85=new_mat[2]
pn_85=new_mat[3]
sn_85=new_mat[4]

# %%
dt = pd.read_excel (r'nd_0.80.xlsx')
mat = dt.to_numpy()
new_mat=np.transpose(mat)
p_80=new_mat[1]
s_80=new_mat[2]
pn_80=new_mat[3]
sn_80=new_mat[4]

# %%
dt = pd.read_excel (r'nd_0.90.xlsx')
mat = dt.to_numpy()
new_mat=np.transpose(mat)
p_90=new_mat[1]
s_90=new_mat[2]
pn_90=new_mat[3]
sn_90=new_mat[4]

# %%
fig,ax = plt.subplots(figsize=(15,9),facecolor = 'white')
#plt.subplot(1,2,1)
plotss = plt.plot(pn_50,sn_50,'--ko', linewidth=1, label = "crack position $h/2$")
plotss = plt.plot(pn_60,sn_60,'-.k*', linewidth=1, label = "crack position $h/2.5$")
plotss = plt.plot(pn_80,sn_80,'-.kh', linewidth=1, label = "crack position $h/5$")
plotss = plt.plot(pn_85,sn_85,'-k+', linewidth=1, label = "crack position $h/6.67$")
plotss = plt.plot(pn_90,sn_90,'--kd', linewidth=1, label = "crack position $h/10$")
plt.xlabel('Normalized length $x/W$')
plt.ylabel('Normalized stresses $\sigma_{yy}/\sigma_{yy(boundary)}$')
plt.xlim([0.66,0.75])
#plt.ylim([0, 13])
plt.rc('axes', titlesize=18) 
plt.rc('xtick', labelsize=18) 
plt.rc('ytick', labelsize=18) 
plt.rc('axes', labelsize=18)

#ax.legend()
plt.legend(loc=1, prop={'size': 16})

plt.title('')
#grids
plt.minorticks_on()
#plt.grid (which='minor', color='g', ls='-.', lw=0.5)
#plt.grid(which='major',color='g', ls='--', lw=0.5)
#################for zooming particular range
#axins = zoomed_inset_axes(ax, 1,loc= 10,borderpad=1) # zoom = 6
#axins.plot(pn_50,sn_50,'--ko')
#axins.plot(pn_60,sn_60,'-.k*')
#axins.plot(pn_80,sn_80,'-.kh')
#axins.plot(pn_85,sn_85,'-k+')
#axins.plot(pn_90,sn_90,'--kd')
#axins.set_xlim(0.666,0.685) # Limit the region for zoom
#axins.set_ylim(3, 6)
#mark_inset(ax, axins, loc1=2, loc2=4, fc="none", ec="0.")
#axins.locator_params(axis='x',nbins=1)
#axins.locator_params(axis='y',nbins=1)


#plt.show()
plt.savefig('6_cases_png',dpi = 1200)
# Out:
# <>:9: SyntaxWarning: invalid escape sequence '\s'
# <>:9: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Ayan Basu\AppData\Local\Temp\ipykernel_32160\3580419005.py:9: SyntaxWarning: invalid escape sequence '\s'
#   plt.ylabel('Normalized stresses $\sigma_{yy}/\sigma_{yy(boundary)}$')
