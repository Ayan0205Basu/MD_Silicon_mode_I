# %%
import matplotlib as mpl
mpl.rcParams['font.family']='serif'
mpl.rcParams['mathtext.fontset']='cm'
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from matplotlib.pyplot import legend,gca
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes
from mpl_toolkits.axes_grid1.inset_locator import mark_inset

# %%
dt = pd.read_excel (r'edge_stress_data.xlsx')
mat = dt.to_numpy()
new_mat=np.transpose(mat)

# %%
new_mat
# Out:
# array([[9.60594000e+05, 9.60602000e+05, 9.60610000e+05, ...,
#         2.88325700e+06, 2.88326500e+06, 2.88327300e+06],
#        [7.27620000e+02, 7.33050000e+02, 7.38480000e+02, ...,
#         2.15571000e+03, 2.16114000e+03, 2.16657000e+03],
#        [2.71771000e+03, 2.71771000e+03, 2.71771000e+03, ...,
#         2.71771000e+03, 2.71771000e+03, 2.71771000e+03],
#        ...,
#        [5.22710000e+06, 4.46037000e+06, 3.19067000e+06, ...,
#         2.75661000e+05, 2.72589000e+05, 2.66474000e+05],
#        [5.23779950e+06, 4.47103870e+06, 3.20134450e+06, ...,
#         2.86326900e+05, 2.83253300e+05, 2.77132200e+05],
#        [2.23741013e+01, 1.90952521e+01, 1.41492763e+01, ...,
#         1.42138630e+00, 1.40651234e+00, 1.37620646e+00]])

# %%
pos_x = new_mat[1]
pos_x = pos_x/10
pos_x
# Out:
# array([ 72.762,  73.305,  73.848,  74.391,  74.934,  75.477,  76.02 ,
#         76.563,  77.106,  77.649,  78.192,  78.735,  79.278,  79.821,
#         80.364,  80.907,  81.45 ,  81.993,  82.536,  83.079,  83.622,
#         84.165,  84.708,  85.251,  85.794,  86.337,  86.88 ,  87.423,
#         87.966,  88.509,  89.052,  89.595,  90.138,  90.681,  91.224,
#         91.767,  92.31 ,  92.853,  93.396,  93.939,  94.482,  95.025,
#         95.568,  96.111,  96.654,  97.197,  97.74 ,  98.283,  98.826,
#         99.369,  99.912, 100.455, 100.998, 101.541, 102.084, 102.627,
#        103.17 , 103.713, 104.256, 104.799, 105.342, 105.885, 106.428,
#        106.971, 107.514, 108.057, 108.6  , 109.143, 109.686, 110.229,
#        110.772, 111.315, 111.858, 112.401, 112.944, 113.487, 114.03 ,
#        114.573, 115.116, 115.659, 116.202, 116.745, 117.288, 117.831,
#        118.374, 118.917, 119.46 , 120.003, 120.546, 121.089, 121.632,
# ...

# %%
sig_yy =new_mat[11]
sig_yy
# Out:
# array([24.43287661, 19.27697361, 14.06433668, 11.54844143, 10.09499877,
#         9.09400004,  8.33691779,  7.69651054,  7.18236127,  6.79293658,
#         6.46476604,  6.2112013 ,  5.95921972,  5.77867367,  5.5568838 ,
#         5.38499397,  5.18780954,  5.03183858,  4.92944225,  4.80620604,
#         4.6195532 ,  4.52494096,  4.41547287,  4.36830628,  4.30147345,
#         4.23491159,  4.11923374,  4.11605387,  4.0364057 ,  3.93763248,
#         3.8560995 ,  3.81659274,  3.77242507,  3.77232336,  3.70981803,
#         3.69967113,  3.64174341,  3.57527653,  3.56152654,  3.45084963,
#         3.40208495,  3.38306999,  3.37937808,  3.33169427,  3.33758217,
#         3.26545428,  3.23675372,  3.22680569,  3.18540727,  3.17622543,
#         3.11632662,  3.15695705,  3.11856126,  3.0918608 ,  2.96421216,
#         3.04966772,  2.99398623,  2.98352769,  3.02579288,  2.94292855,
#         2.96165675,  2.94685711,  2.95660505,  2.90554441,  2.88184218,
# ...

# %%
fig,ax = plt.subplots(figsize=(15,9),facecolor = 'white')
#plt.subplot(1,2,1)
plotss = plt.plot(pos_x,sig_yy,'--ko', linewidth=1, label = "$\sigma_{yy}$ curve obtained from MD")
plt.xlabel('X co-ordinate of atom position (nm)')
plt.ylabel('$\sigma_{yy}$ (GPa)')
#plt.xlim([0.66,0.75])
#plt.ylim([0, 13])
plt.rc('axes', titlesize=18) 
plt.rc('xtick', labelsize=18) 
plt.rc('ytick', labelsize=18) 
plt.rc('axes', labelsize=18)

#ax.legend()
plt.legend(loc=1, prop={'size': 18})
plt.legend(loc=1, prop={'size': 18})
plt.title('')
#grids
plt.minorticks_on()
#plt.grid (which='minor', color='g', ls='-.', lw=0.5)
#plt.grid(which='major',color='g', ls='--', lw=0.5)
#################for zooming particular range


#plt.show()
plt.savefig('edge_s_local.pdf',dpi = 1200)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Ayan Basu\AppData\Local\Temp\ipykernel_18672\2105434.py:3: SyntaxWarning: invalid escape sequence '\s'
#   plotss = plt.plot(pos_x,sig_yy,'--ko', linewidth=1, label = "$\sigma_{yy}$ curve obtained from MD")
# C:\Users\Ayan Basu\AppData\Local\Temp\ipykernel_18672\2105434.py:5: SyntaxWarning: invalid escape sequence '\s'
#   plt.ylabel('$\sigma_{yy}$ (GPa)')

# %%
boundary_stress = 2.201778333
total_width = 217.2

# %%
normalized_stress = sig_yy/boundary_stress
normalized_x = pos_x/total_width
normalized_stress,normalized_x
# Out:
# (array([11.09688302,  8.75518363,  6.38771691,  5.24505181,  4.58492965,
#          4.13029772,  3.78644737,  3.49558828,  3.26207283,  3.08520457,
#          2.93615663,  2.82099301,  2.70654845,  2.62454834,  2.52381619,
#          2.44574755,  2.35619066,  2.28535203,  2.23884583,  2.18287462,
#          2.09810094,  2.05513011,  2.00541208,  1.98399004,  1.95363602,
#          1.92340506,  1.87086669,  1.86942246,  1.83324799,  1.78838733,
#          1.75135682,  1.7334137 ,  1.71335371,  1.71330751,  1.68491895,
#          1.68031044,  1.65400093,  1.62381311,  1.61756816,  1.56730111,
#          1.54515325,  1.53651707,  1.53484028,  1.51318333,  1.51585749,
#          1.48309856,  1.47006339,  1.46554521,  1.44674294,  1.44257275,
#          1.41536801,  1.43382147,  1.41638294,  1.40425616,  1.34628092,
#          1.38509298,  1.35980366,  1.35505361,  1.37424955,  1.33661436,
#          1.34512031,  1.33839863,  1.34282594,  1.3196353 ,  1.30887026,
# ...

# %%
fig,ax = plt.subplots(figsize=(15,9),facecolor = 'white')
#plt.subplot(1,2,1)
plotss = plt.plot(normalized_x,normalized_stress,'--ko', linewidth=1, label = "normalized data for edge crack")
ax.annotate('1$^{\mathrm{st}}$ atomic site', xy=(0.336, 11.10688302), xytext=(0.366, 12.10688302), fontsize=18,
            arrowprops=dict(facecolor='gray',arrowstyle="->"))
ax.annotate('2$^{\mathrm{nd}}$ atomic site', xy=(0.3385, 8.75518363), xytext=(0.3685, 9.75518363), fontsize=18,
            arrowprops=dict(facecolor='gray',arrowstyle="->"))
ax.annotate('3$^{\mathrm{rd}}$ atomic site', xy=(0.341, 6.38771691), xytext=(0.371, 7.38771691), fontsize=18,
            arrowprops=dict(facecolor='gray',arrowstyle="->"))
ax.annotate('4$^{\mathrm{th}}$ atomic site', xy=(0.3425, 5.24505181), xytext=(0.3725, 4.24505181), fontsize=18,
            arrowprops=dict(facecolor='gray',arrowstyle="->"))

plt.xlabel('Normalized length $x/W$')
plt.ylabel('Normalized stresses $\sigma_{yy}/\sigma_{yy(boundary)}$')
#plt.xlim([0.66,0.75])
plt.ylim([0, 13])
plt.rc('axes', titlesize=18) 
plt.rc('xtick', labelsize=18) 
plt.rc('ytick', labelsize=18) 
plt.rc('axes', labelsize=18)

#ax.legend()
plt.legend(loc=1, prop={'size': 18})
plt.legend(loc=1, prop={'size': 18})
plt.title('')
#grids
plt.minorticks_on()
#plt.grid (which='minor', color='g', ls='-.', lw=0.5)
#plt.grid(which='major',color='g', ls='--', lw=0.5)
#################for zooming particular range
axins = zoomed_inset_axes(ax, 3,loc= 10,borderpad=1) # zoom = 6
axins.plot(normalized_x,normalized_stress,'--ko')
axins.annotate('5$^{\mathrm{th}}$ atomic site', xy=(0.345, 4.5849), xytext=(0.385, 4.8849), fontsize=18,
            arrowprops=dict(facecolor='gray',arrowstyle="->"))
axins.annotate('6$^{\mathrm{th}}$ atomic site', xy=(0.3475, 4.13029772), xytext=(0.3875, 4.43029772), fontsize=18,
            arrowprops=dict(facecolor='gray',arrowstyle="->"))
axins.annotate('7$^{\mathrm{th}}$ atomic site', xy=(0.35, 3.78644737), xytext=(0.39, 4.08644737), fontsize=18,
            arrowprops=dict(facecolor='gray',arrowstyle="->"))
axins.annotate('8$^{\mathrm{th}}$ atomic site', xy=(0.3525, 3.49558828), xytext=(0.3925, 3.79558828), fontsize=18,
            arrowprops=dict(facecolor='gray',arrowstyle="->"))
axins.annotate('9$^{\mathrm{th}}$ atomic site', xy=(0.355, 3.26207283), xytext=(0.395, 3.56207283), fontsize=18,
            arrowprops=dict(facecolor='gray',arrowstyle="->"))
axins.annotate('10$^{\mathrm{th}}$ atomic site', xy=(0.3575, 3.08520457), xytext=(0.3975, 3.08520457), fontsize=18,
            arrowprops=dict(facecolor='gray',arrowstyle="->"))
axins.annotate('11$^{\mathrm{th}}$ atomic site', xy=(0.36, 2.93615663), xytext=(0.40, 2.63615663), fontsize=18,
            arrowprops=dict(facecolor='gray',arrowstyle="->"))
axins.set_xlim(0.34,0.372) # Limit the region for zoom
axins.set_ylim(2.44,4.6)
mark_inset(ax, axins, loc1=2, loc2=4, fc="none", ec="0.")
axins.locator_params(axis='x',nbins=1)
axins.locator_params(axis='y',nbins=1)


#plt.show()
plt.savefig('fig_edge.pdf',dpi = 1200)
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\m'
# <>:6: SyntaxWarning: invalid escape sequence '\m'
# <>:8: SyntaxWarning: invalid escape sequence '\m'
# <>:10: SyntaxWarning: invalid escape sequence '\m'
# <>:14: SyntaxWarning: invalid escape sequence '\s'
# <>:33: SyntaxWarning: invalid escape sequence '\m'
# <>:35: SyntaxWarning: invalid escape sequence '\m'
# <>:37: SyntaxWarning: invalid escape sequence '\m'
# <>:39: SyntaxWarning: invalid escape sequence '\m'
# <>:41: SyntaxWarning: invalid escape sequence '\m'
# <>:43: SyntaxWarning: invalid escape sequence '\m'
# <>:45: SyntaxWarning: invalid escape sequence '\m'
# <>:4: SyntaxWarning: invalid escape sequence '\m'
# <>:6: SyntaxWarning: invalid escape sequence '\m'
# <>:8: SyntaxWarning: invalid escape sequence '\m'
# <>:10: SyntaxWarning: invalid escape sequence '\m'
# <>:14: SyntaxWarning: invalid escape sequence '\s'
# <>:33: SyntaxWarning: invalid escape sequence '\m'
# ...

# %%
xx = pos_x-(total_width/3)
xx
# Out:
# array([  0.362,   0.905,   1.448,   1.991,   2.534,   3.077,   3.62 ,
#          4.163,   4.706,   5.249,   5.792,   6.335,   6.878,   7.421,
#          7.964,   8.507,   9.05 ,   9.593,  10.136,  10.679,  11.222,
#         11.765,  12.308,  12.851,  13.394,  13.937,  14.48 ,  15.023,
#         15.566,  16.109,  16.652,  17.195,  17.738,  18.281,  18.824,
#         19.367,  19.91 ,  20.453,  20.996,  21.539,  22.082,  22.625,
#         23.168,  23.711,  24.254,  24.797,  25.34 ,  25.883,  26.426,
#         26.969,  27.512,  28.055,  28.598,  29.141,  29.684,  30.227,
#         30.77 ,  31.313,  31.856,  32.399,  32.942,  33.485,  34.028,
#         34.571,  35.114,  35.657,  36.2  ,  36.743,  37.286,  37.829,
#         38.372,  38.915,  39.458,  40.001,  40.544,  41.087,  41.63 ,
#         42.173,  42.716,  43.259,  43.802,  44.345,  44.888,  45.431,
#         45.974,  46.517,  47.06 ,  47.603,  48.146,  48.689,  49.232,
# ...

# %%
stresses_mpa = sig_yy*1000
xx_m = xx*10**(-9)
stresses_mpa
# Out:
# array([24432.87660583, 19276.97360984, 14064.33668312, 11548.44142866,
#        10094.99877031,  9094.00003851,  8336.9177875 ,  7696.51054416,
#         7182.36127058,  6792.93658154,  6464.76604305,  6211.20129551,
#         5959.21972442,  5778.67367273,  5556.88379549,  5384.99397282,
#         5187.80954215,  5031.83858481,  4929.44224845,  4806.20604284,
#         4619.55319791,  4524.94095658,  4415.47286945,  4368.30628288,
#         4301.47345436,  4234.91158527,  4119.23374217,  4116.05386571,
#         4036.40570349,  3937.63248096,  3856.0994967 ,  3816.59273565,
#         3772.42507004,  3772.32336072,  3709.81802998,  3699.67112625,
#         3641.74341346,  3575.27652911,  3561.52653716,  3450.84962833,
#         3402.08495178,  3383.06998866,  3379.37808082,  3331.69427381,
#         3337.58217257,  3265.45427807,  3236.75371675,  3226.80568709,
#         3185.40726579,  3176.22542546,  3116.32662344,  3156.95704759,
# ...

# %%
Y_inv = np.sqrt(2*np.pi*xx_m)
YY = 1/Y_inv
xx_m
# Out:
# array([3.62000e-10, 9.05000e-10, 1.44800e-09, 1.99100e-09, 2.53400e-09,
#        3.07700e-09, 3.62000e-09, 4.16300e-09, 4.70600e-09, 5.24900e-09,
#        5.79200e-09, 6.33500e-09, 6.87800e-09, 7.42100e-09, 7.96400e-09,
#        8.50700e-09, 9.05000e-09, 9.59300e-09, 1.01360e-08, 1.06790e-08,
#        1.12220e-08, 1.17650e-08, 1.23080e-08, 1.28510e-08, 1.33940e-08,
#        1.39370e-08, 1.44800e-08, 1.50230e-08, 1.55660e-08, 1.61090e-08,
#        1.66520e-08, 1.71950e-08, 1.77380e-08, 1.82810e-08, 1.88240e-08,
#        1.93670e-08, 1.99100e-08, 2.04530e-08, 2.09960e-08, 2.15390e-08,
#        2.20820e-08, 2.26250e-08, 2.31680e-08, 2.37110e-08, 2.42540e-08,
#        2.47970e-08, 2.53400e-08, 2.58830e-08, 2.64260e-08, 2.69690e-08,
#        2.75120e-08, 2.80550e-08, 2.85980e-08, 2.91410e-08, 2.96840e-08,
#        3.02270e-08, 3.07700e-08, 3.13130e-08, 3.18560e-08, 3.23990e-08,
#        3.29420e-08, 3.34850e-08, 3.40280e-08, 3.45710e-08, 3.51140e-08,
# ...

# %%
#remove the entry of the first atom
YY = YY[1:]
stresses_mpa = stresses_mpa[1:]

# %%
fig,ax = plt.subplots(figsize=(15,9),facecolor = 'white')
#plt.subplot(1,2,1)
plotss = plt.plot(YY,stresses_mpa,'--ko', linewidth=1, label = "normalized data for edge crack")
plt.xlabel('$x/W$')
plt.ylabel('$\sigma_{yy}/\sigma_{yy(boundary)}$')
#plt.xlim([0.66,0.75])
#plt.ylim([0, 13])
plt.rc('axes', titlesize=18) 
plt.rc('xtick', labelsize=18) 
plt.rc('ytick', labelsize=18) 
plt.rc('axes', labelsize=18)

#ax.legend()
plt.legend(loc=1, prop={'size': 18})
plt.legend(loc=1, prop={'size': 18})
plt.title('')
#grids
plt.minorticks_on()
#plt.grid (which='minor', color='g', ls='-.', lw=0.5)
#plt.grid(which='major',color='g', ls='--', lw=0.5)
#################for zooming particular range


plt.show()
#plt.savefig('edge_s_local_normalized.pdf',dpi = 1200)
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Ayan Basu\AppData\Local\Temp\ipykernel_18672\685089706.py:5: SyntaxWarning: invalid escape sequence '\s'
#   plt.ylabel('$\sigma_{yy}/\sigma_{yy(boundary)}$')

# %%
ss_cut =stresses_mpa[4:5]
y_cut = YY[4:5]

# %%
m_x = np.mean(y_cut)
m_y = np.mean(ss_cut)
kic = m_y/m_x
kic
# Out:
# np.float64(1.2644703027994222)

# %%
b_0 = 0     
b_1 = 1.2715261882993458

# %%
stress_fit = b_1 * y_cut + b_0 
error = ss_cut - stress_fit
n_1 = np.size(y_cut)
ss_mean = np.mean(ss_cut)
se = np.sum(error**2)
print('squared error is', se)
mse = se/n_1 
print('mean squared error is', mse)
SSt = np.sum((ss_cut - ss_mean)**2)
R2 = 1- (se/SSt)
print('R square is', R2)
# Out:
# squared error is 2575.109402771075
# mean squared error is 2575.109402771075
# R square is -inf
# C:\Users\Ayan Basu\AppData\Local\Temp\ipykernel_18672\2174593048.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   R2 = 1- (se/SSt)

# %%
for i in range(3,12):
    print(i+1)
    ss_cut =stresses_mpa[2:i]
    y_cut = YY[2:i]

    m_x = np.mean(y_cut)
    m_y = np.mean(ss_cut)
    kic = m_y/m_x
    print(kic)

    b_0 = 0     
    b_1 = kic

    stress_fit = b_1 * y_cut + b_0 
    error = ss_cut - stress_fit
    n_1 = np.size(y_cut)
    ss_mean = np.mean(ss_cut)
    se = np.sum(error**2)
    print('squared error is', se)
    mse = se/n_1 
    print('mean squared error is', mse)
    SSt = np.sum((ss_cut - ss_mean)**2)
    R2 = 1- (se/SSt)
    print('R square is', R2)
# Out:
# 4
# 1.291662170044868
# squared error is 0.0
# mean squared error is 0.0
# R square is nan
# 5
# 1.2832665024573695
# squared error is 11269.102716359204
# mean squared error is 5634.551358179602
# R square is 0.989331004595914
# 6
# 1.277647493592945
# squared error is 25614.054484741493
# mean squared error is 8538.018161580498
# R square is 0.9915916356034001
# 7
# 1.2732579237624226
# squared error is 42240.503228871385
# mean squared error is 10560.125807217846
# R square is 0.9926909058105498
# 8
# 1.2684796867261137
# squared error is 72532.99110978108
# mean squared error is 14506.598221956217
# R square is 0.9921279410891262
# 9
# 1.263924859881156
# squared error is 111786.8739577221
# mean squared error is 18631.14565962035
# R square is 0.9914956181875252
# 10
# 1.260463735150566
# squared error is 143331.52777953135
# mean squared error is 20475.93253993305
# R square is 0.9917103565936689
# 11
# 1.2577957296657147
# squared error is 168305.98873969296
# ...

# %%
fig,ax = plt.subplots(figsize=(9,9),facecolor = 'white')
#plt.subplot(1,2,1)
plotss = plt.plot(y_cut,ss_cut,'ko', linewidth=1, label = "data points")
plotss = plt.plot(y_cut,stress_fit,'-k', linewidth=1, label = "linear fit")
plt.xlabel('($\sqrt{2 \pi x})^{-1}$ ($\sqrt{\mathrm{m}}^{-1}$)')
plt.ylabel('Stress ($\sigma^{atom}_{yy}$) (MPa)')
plt.text(6200, 8100, 'slope = 1.2969 MPa$\sqrt{\mathrm{m}}$', color='black',
         rotation=42, rotation_mode='anchor', fontsize = 24)
plt.text(7000, 8000, '$\mathrm{R}^2$ = 99.60%', color='black',
         rotation=42, rotation_mode='anchor', fontsize = 24)

#plt.ylim([0, 13])
plt.rc('axes', titlesize=24)
plt.rc('xtick', labelsize=25) 
plt.rc('ytick', labelsize=25) 
plt.rc('axes', labelsize=27)

#ax.legend()
#plt.legend(loc = 2, prop={'size': 22})
#plt.legend(loc = 'upper center',bbox_to_anchor=(0.5, 1.15), ncol=2, fancybox=True, shadow=False, prop={'size': 24})

plt.title('')
#grids
plt.minorticks_on()
#plt.grid (which='minor', color='g', ls='-.', lw=0.5)
#plt.grid(which='major',color='g', ls='--', lw=0.5)
#################for zooming particular range


plt.savefig('sif_edge.pdf',dpi = 1200, bbox_inches='tight')
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:6: SyntaxWarning: invalid escape sequence '\s'
# <>:7: SyntaxWarning: invalid escape sequence '\s'
# <>:9: SyntaxWarning: invalid escape sequence '\m'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:6: SyntaxWarning: invalid escape sequence '\s'
# <>:7: SyntaxWarning: invalid escape sequence '\s'
# <>:9: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\Ayan Basu\AppData\Local\Temp\ipykernel_18672\1511198438.py:5: SyntaxWarning: invalid escape sequence '\s'
#   plt.xlabel('($\sqrt{2 \pi x})^{-1}$ ($\sqrt{\mathrm{m}}^{-1}$)')
# C:\Users\Ayan Basu\AppData\Local\Temp\ipykernel_18672\1511198438.py:6: SyntaxWarning: invalid escape sequence '\s'
#   plt.ylabel('Stress ($\sigma^{atom}_{yy}$) (MPa)')
# C:\Users\Ayan Basu\AppData\Local\Temp\ipykernel_18672\1511198438.py:7: SyntaxWarning: invalid escape sequence '\s'
#   plt.text(6200, 8100, 'slope = 1.2969 MPa$\sqrt{\mathrm{m}}$', color='black',
# ...
