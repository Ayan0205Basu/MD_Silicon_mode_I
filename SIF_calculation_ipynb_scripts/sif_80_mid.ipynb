# %%
import matplotlib as mpl
mpl.rcParams['font.family']='serif'
mpl.rcParams['mathtext.fontset']='cm'
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from matplotlib.pyplot import legend,gca
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes
from mpl_toolkits.axes_grid1.inset_locator import mark_inset

# %%
dt = pd.read_excel (r'stress_data_80.xlsx')
mat = dt.to_numpy()
new_mat=np.transpose(mat)

# %%
pos_x = new_mat[1]
pos_x = pos_x/10
pos_x
# Out:
# array([144.981, 145.524, 146.067, 146.61 , 147.153, 147.696, 148.239,
#        148.782, 149.325, 149.868, 150.411, 150.954, 151.497, 152.04 ,
#        152.583, 153.126, 153.669, 154.212, 154.755, 155.298, 155.841,
#        156.384, 156.927, 157.47 , 158.013, 158.556, 159.099, 159.642,
#        160.185, 160.728, 161.271, 161.814, 162.357, 162.9  , 163.443,
#        163.986, 164.529, 165.072, 165.615, 166.158, 166.701, 167.244,
#        167.787, 168.33 , 168.873, 169.416, 169.959, 170.502, 171.045,
#        171.588, 172.131, 172.674, 173.217, 173.76 , 174.303, 174.846,
#        175.389, 175.932, 176.475, 177.018, 177.561, 178.104, 178.647,
#        179.19 , 179.733, 180.276, 180.819, 181.362, 181.905, 182.448,
#        182.991, 183.534, 184.077, 184.62 , 185.163, 185.706, 186.249,
#        186.792, 187.335, 187.878, 188.421, 188.964, 189.507, 190.05 ,
#        190.593, 191.136, 191.679, 192.222, 192.765, 193.308, 193.851,
#        194.394, 194.937, 195.48 , 196.023, 196.566, 197.109, 197.652,
#        198.195, 198.738, 199.281, 199.824, 200.367, 200.91 , 201.453,
#        201.996, 202.539, 203.082, 203.625, 204.168, 204.711, 205.254,
#        205.797, 206.34 , 206.883, 207.426, 207.969, 208.512, 209.055,
#        209.598, 210.141, 210.684, 211.227, 211.77 , 212.313, 212.856,
#        213.399, 213.942, 214.485, 215.028, 215.571, 216.114, 216.657])

# %%
sig_yy =new_mat[12]
sig_yy
# Out:
# array([17.12435696, 12.20928588,  9.09295072,  7.55597135,  6.65209917,
#         6.0207838 ,  5.51514789,  5.1200246 ,  4.88500192,  4.61902112,
#         4.38817464,  4.22482316,  4.12502295,  3.98521648,  3.8806619 ,
#         3.76810631,  3.66284233,  3.58732496,  3.53008679,  3.49752916,
#         3.51224992,  3.47339314,  3.49291673,  3.48223524,  3.47242322,
#         3.47165181,  3.47131362,  3.44698438,  3.46346289,  3.44745002,
#         3.44561083,  3.44510683,  3.44431794,  3.44232216,  3.41908836,
#         3.43637278,  3.43249873,  3.43106032,  3.42878635,  3.42730746,
#         3.42422431,  3.41899667,  3.41635916,  3.40772417,  3.40358851,
#         3.36904286,  3.38358538,  3.38186405,  3.37581411,  3.351078  ,
#         3.36447517,  3.36195521,  3.35264782,  3.34353126,  3.33583664,
#         3.29357576,  3.31517576,  3.32672825,  3.32310376,  3.32025216,
#         3.30183482,  3.28045627,  3.2747011 ,  3.24815013,  3.2459831 ,
#         3.24335107,  3.24995133,  3.23881774,  3.23191568,  3.20179169,
#         3.18986991,  3.19784583,  3.17354395,  3.16922549,  3.13662266,
#         3.11176481,  3.1300719 ,  3.12624576,  3.09229913,  3.10475196,
#         3.10390848,  3.09657075,  3.07948431,  3.07301811,  3.06279701,
#         3.0542718 ,  3.0478283 ,  3.02756845,  3.02496354,  3.01538367,
#         3.01415168,  3.01079518,  2.99797474,  2.95709303,  2.93910134,
#         2.92997639,  2.89897102,  2.88841515,  2.8538936 ,  2.83273658,
#         2.82201985,  2.82003715,  2.80078489,  2.78210839,  2.7528343 ,
#         2.74487177,  2.73458278,  2.72711916,  2.72419948,  2.71006224,
#         2.70710779,  2.70149904,  2.69877625,  2.68469019,  2.67898345,
#         2.67662211,  2.66871482,  2.66417603,  2.66044292,  2.65826021,
#         2.65188416,  2.64601116,  2.64316967,  2.63829998,  2.63864919,
#         2.62967885,  2.62606635,  2.62664803,  2.62060078,  2.61666975,
#         2.60105535,  2.60176981,  2.59631812])

# %%
fig,ax = plt.subplots(figsize=(15,9),facecolor = 'white')
#plt.subplot(1,2,1)
plotss = plt.plot(pos_x,sig_yy,'--ko', linewidth=1, label = "$\sigma_{yy}$ curve obtained from MD")
plt.xlabel('X co-ordinate of atom position (nm)')
plt.ylabel('$\sigma_{yy}$ (GPa)')
#plt.xlim([0.66,0.75])
#plt.ylim([0, 13])
plt.rc('axes', titlesize=18) 
plt.rc('xtick', labelsize=18) 
plt.rc('ytick', labelsize=18) 
plt.rc('axes', labelsize=18)

#ax.legend()
plt.legend(loc=1, prop={'size': 18})
plt.legend(loc=1, prop={'size': 18})
plt.title('')
#grids
plt.minorticks_on()
#plt.grid (which='minor', color='g', ls='-.', lw=0.5)
#plt.grid(which='major',color='g', ls='--', lw=0.5)
#################for zooming particular range


#plt.show()
plt.savefig('mid_80_s_local.pdf',dpi = 1200)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Ayan Basu\AppData\Local\Temp\ipykernel_8756\2737313427.py:3: SyntaxWarning: invalid escape sequence '\s'
#   plotss = plt.plot(pos_x,sig_yy,'--ko', linewidth=1, label = "$\sigma_{yy}$ curve obtained from MD")
# C:\Users\Ayan Basu\AppData\Local\Temp\ipykernel_8756\2737313427.py:5: SyntaxWarning: invalid escape sequence '\s'
#   plt.ylabel('$\sigma_{yy}$ (GPa)')

# %%
boundary_stress = 1.880521246
total_width = 217.2

# %%
normalized_stress = sig_yy/boundary_stress
normalized_x = pos_x/total_width

# %%
fig,ax = plt.subplots(figsize=(15,9),facecolor = 'white')
#plt.subplot(1,2,1)
plotss = plt.plot(normalized_x,normalized_stress,'--ko', linewidth=1, label = "normalized data for edge crack")
plt.xlabel('$x/W$')
plt.ylabel('$\sigma_{yy}/\sigma_{yy(boundary)}$')
#plt.xlim([0.66,0.75])
#plt.ylim([0, 13])
plt.rc('axes', titlesize=18) 
plt.rc('xtick', labelsize=18) 
plt.rc('ytick', labelsize=18) 
plt.rc('axes', labelsize=18)

#ax.legend()
plt.legend(loc=1, prop={'size': 18})
plt.legend(loc=1, prop={'size': 18})
plt.title('')
#grids
plt.minorticks_on()
#plt.grid (which='minor', color='g', ls='-.', lw=0.5)
#plt.grid(which='major',color='g', ls='--', lw=0.5)
#################for zooming particular range


#plt.show()
plt.savefig('mid_80_s_local_normalized.pdf',dpi = 1200)
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Ayan Basu\AppData\Local\Temp\ipykernel_8756\3829193229.py:5: SyntaxWarning: invalid escape sequence '\s'
#   plt.ylabel('$\sigma_{yy}/\sigma_{yy(boundary)}$')

# %%
xx = pos_x-(2*total_width/3)
xx
# Out:
# array([ 0.181,  0.724,  1.267,  1.81 ,  2.353,  2.896,  3.439,  3.982,
#         4.525,  5.068,  5.611,  6.154,  6.697,  7.24 ,  7.783,  8.326,
#         8.869,  9.412,  9.955, 10.498, 11.041, 11.584, 12.127, 12.67 ,
#        13.213, 13.756, 14.299, 14.842, 15.385, 15.928, 16.471, 17.014,
#        17.557, 18.1  , 18.643, 19.186, 19.729, 20.272, 20.815, 21.358,
#        21.901, 22.444, 22.987, 23.53 , 24.073, 24.616, 25.159, 25.702,
#        26.245, 26.788, 27.331, 27.874, 28.417, 28.96 , 29.503, 30.046,
#        30.589, 31.132, 31.675, 32.218, 32.761, 33.304, 33.847, 34.39 ,
#        34.933, 35.476, 36.019, 36.562, 37.105, 37.648, 38.191, 38.734,
#        39.277, 39.82 , 40.363, 40.906, 41.449, 41.992, 42.535, 43.078,
#        43.621, 44.164, 44.707, 45.25 , 45.793, 46.336, 46.879, 47.422,
#        47.965, 48.508, 49.051, 49.594, 50.137, 50.68 , 51.223, 51.766,
#        52.309, 52.852, 53.395, 53.938, 54.481, 55.024, 55.567, 56.11 ,
#        56.653, 57.196, 57.739, 58.282, 58.825, 59.368, 59.911, 60.454,
#        60.997, 61.54 , 62.083, 62.626, 63.169, 63.712, 64.255, 64.798,
#        65.341, 65.884, 66.427, 66.97 , 67.513, 68.056, 68.599, 69.142,
#        69.685, 70.228, 70.771, 71.314, 71.857])

# %%
stresses_mpa = sig_yy*1000
xx_m = xx*10**(-9)
stresses_mpa
# Out:
# array([17124.35695937, 12209.28587737,  9092.9507192 ,  7555.97134744,
#         6652.09917494,  6020.78380125,  5515.14788646,  5120.02460288,
#         4885.00192027,  4619.0211197 ,  4388.17463935,  4224.82315762,
#         4125.0229452 ,  3985.21648373,  3880.66190072,  3768.10631395,
#         3662.84233139,  3587.32496289,  3530.08678926,  3497.52915692,
#         3512.24992418,  3473.39314114,  3492.91673302,  3482.23524228,
#         3472.42321946,  3471.65180896,  3471.31362346,  3446.98438251,
#         3463.46288787,  3447.4500193 ,  3445.61082529,  3445.10682696,
#         3444.31793747,  3442.3221645 ,  3419.08835775,  3436.37278221,
#         3432.49872952,  3431.06032189,  3428.78634913,  3427.30745677,
#         3424.22431385,  3418.99667223,  3416.35915546,  3407.72417348,
#         3403.58850657,  3369.04286283,  3383.58538469,  3381.86404755,
#         3375.81411295,  3351.07799961,  3364.47517165,  3361.95521342,
#         3352.64781785,  3343.5312564 ,  3335.83663597,  3293.57575654,
#         3315.17576359,  3326.72824597,  3323.1037579 ,  3320.25216413,
#         3301.83482376,  3280.45626991,  3274.70110256,  3248.15013298,
#         3245.98309691,  3243.35106822,  3249.95133388,  3238.81774444,
#         3231.9156831 ,  3201.79169216,  3189.86991075,  3197.84582662,
#         3173.54395253,  3169.22548758,  3136.62265935,  3111.7648054 ,
#         3130.07190042,  3126.24575729,  3092.29912974,  3104.75196403,
#         3103.90848456,  3096.57075457,  3079.48430605,  3073.01811344,
#         3062.79700631,  3054.27180068,  3047.82829832,  3027.56844573,
#         3024.96353539,  3015.38367344,  3014.15167646,  3010.79518161,
#         2997.97473917,  2957.09303098,  2939.10133808,  2929.97639337,
#         2898.97102371,  2888.41514631,  2853.89360259,  2832.73658034,
#         2822.01985395,  2820.03714572,  2800.78489493,  2782.10839424,
#         2752.83430371,  2744.87177152,  2734.58278035,  2727.11915559,
#         2724.19948073,  2710.062244  ,  2707.10779352,  2701.49904059,
#         2698.77624749,  2684.69018865,  2678.98344504,  2676.62211137,
#         2668.71482056,  2664.17602793,  2660.44292386,  2658.26020713,
#         2651.88415567,  2646.01115878,  2643.16967107,  2638.29997603,
#         2638.64918997,  2629.67885097,  2626.06634713,  2626.64803318,
#         2620.60077729,  2616.66975466,  2601.05534582,  2601.76981412,
#         2596.31812028])

# %%
Y_inv = np.sqrt(2*np.pi*xx_m)
YY = 1/Y_inv
YY
# Out:
# array([29653.14617129, 14826.57308564, 11207.8357657 ,  9377.14816912,
#         8224.30299995,  7413.28654282,  6802.89829046,  6322.07200592,
#         5930.62923426,  5603.91788285,  5325.86227414,  5085.4726134 ,
#         4874.94720098,  4688.57408456,  4522.06239699,  4372.11787764,
#         4236.16373876,  4112.15149998,  3998.42941406,  3893.64884682,
#         3796.69631597,  3706.64327141,  3622.70839116,  3544.22886607,
#         3470.63824586,  3401.44914523,  3336.23959817,  3274.64218462,
#         3216.33528735,  3161.03600296,  3108.49434925,  3058.48849795,
#         3010.82082492,  2965.31461713,  2921.81131123,  2880.16816506,
#         2840.25628424,  2801.95894142,  2765.17013842,  2729.79337061,
#         2695.74056103,  2662.93113707,  2631.29122798,  2600.75296472,
#         2571.25386729,  2542.7363067 ,  2515.14703127,  2488.43674818,
#         2462.55975297,  2437.47360049,  2413.13881204,  2389.51861404,
#         2366.57870425,  2344.28704228,  2322.61366137,  2301.53049897,
#         2281.01124395,  2261.03119849,  2241.56715314,  2222.59727338,
#         2204.10099669,  2186.05893882,  2168.45280837,  2151.26532883,
#         2134.48016733,  2118.08186938,  2102.05579902,  2086.38808396,
#         2071.06556509,  2056.07574999,  2041.40677015,  2027.04734147,
#         2012.98672776,  1999.21470703,  1985.7215402 ,  1972.49794223,
#         1959.5350552 ,  1946.82442341,  1934.35797019,  1922.12797633,
#         1910.12705999,  1898.34815798,  1886.78450831,  1875.42963382,
#         1864.27732701,  1853.32163571,  1842.55684977,  1831.97748854,
#         1821.57828918,  1811.35419558,  1801.30034811,  1791.41207388,
#         1781.68487761,  1772.11443303,  1762.69657486,  1753.42729112,
#         1744.30271596,  1735.31912293,  1726.47291855,  1717.76063628,
#         1709.17893079,  1700.72457261,  1692.39444299,  1684.18552906,
#         1676.09491928,  1668.11979909,  1660.25744676,  1652.50522956,
#         1644.86059999,  1637.32109231,  1629.88431915,  1622.5479684 ,
#         1615.3098001 ,  1608.16764368,  1601.1193951 ,  1594.16301436,
#         1587.29652294,  1580.51800148,  1573.8255875 ,  1567.21747327,
#         1560.69190375,  1554.24717462,  1547.88163044,  1541.59366282,
#         1535.38170875,  1529.24424897,  1523.17980638,  1517.18694456,
#         1511.26426635,  1505.41041246,  1499.62406018,  1493.90392213,
#         1488.24874503])

# %%
#remove the entry of the first atom
YY = YY[1:]
stresses_mpa = stresses_mpa[1:]

# %%
fig,ax = plt.subplots(figsize=(15,9),facecolor = 'white')
#plt.subplot(1,2,1)
plotss = plt.plot(YY,stresses_mpa,'--ko', linewidth=1, label = "normalized data for edge crack")
plt.xlabel('$x/W$')
plt.ylabel('$\sigma_{yy}/\sigma_{yy(boundary)}$')
#plt.xlim([0.66,0.75])
#plt.ylim([0, 13])
plt.rc('axes', titlesize=18) 
plt.rc('xtick', labelsize=18) 
plt.rc('ytick', labelsize=18) 
plt.rc('axes', labelsize=18)

#ax.legend()
plt.legend(loc=1, prop={'size': 18})
plt.legend(loc=1, prop={'size': 18})
plt.title('')
#grids
plt.minorticks_on()
#plt.grid (which='minor', color='g', ls='-.', lw=0.5)
#plt.grid(which='major',color='g', ls='--', lw=0.5)
#################for zooming particular range


plt.show()
#plt.savefig('edge_s_local_normalized.pdf',dpi = 1200)
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Ayan Basu\AppData\Local\Temp\ipykernel_8756\685089706.py:5: SyntaxWarning: invalid escape sequence '\s'
#   plt.ylabel('$\sigma_{yy}/\sigma_{yy(boundary)}$')

# %%
ss_cut =stresses_mpa[4:5]
y_cut = YY[4:5]

# %%
m_x = np.mean(y_cut)
m_y = np.mean(ss_cut)
kic = m_y/m_x
kic
# Out:
# np.float64(0.8121612143915329)

# %%
b_0 = 0     
b_1 = 0.8097054985186047

# %%
stress_fit = b_1 * y_cut + b_0 
error = ss_cut - stress_fit
n_1 = np.size(y_cut)
ss_mean = np.mean(ss_cut)
se = np.sum(error**2)
print('squared error is', se)
mse = se/n_1 
print('mean squared error is', mse)
SSt = np.sum((ss_cut - ss_mean)**2)
R2 = 1- (se/SSt)
print('R square is', R2)
# Out:
# squared error is 331.41931004922003
# mean squared error is 331.41931004922003
# R square is -inf
# C:\Users\Ayan Basu\AppData\Local\Temp\ipykernel_8756\2174593048.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   R2 = 1- (se/SSt)

# %%
for i in range(2,10):
    print(i+1)
    ss_cut =stresses_mpa[0:i]
    y_cut = YY[0:i]

    m_x = np.mean(y_cut)
    m_y = np.mean(ss_cut)
    kic = m_y/m_x
    print(kic)

    b_0 = 0     
    b_1 = kic

    stress_fit = b_1 * y_cut + b_0 
    error = ss_cut - stress_fit
    n_1 = np.size(y_cut)
    ss_mean = np.mean(ss_cut)
    se = np.sum(error**2)
    print('squared error is', se)
    mse = se/n_1 
    print('mean squared error is', mse)
    SSt = np.sum((ss_cut - ss_mean)**2)
    R2 = 1- (se/SSt)
    print('R square is', R2)
# Out:
# 3
# 0.8182339271925346
# squared error is 12068.599300147678
# mean squared error is 6034.299650073839
# R square is 0.9975145871174437
# 4
# 0.8149375619755135
# squared error is 25040.334194142353
# mean squared error is 8346.778064714117
# R square is 0.9977726869528805
# 5
# 0.8137872635565839
# squared error is 28688.05601328676
# mean squared error is 7172.01400332169
# R square is 0.9983924714307734
# 6
# 0.8135511309431169
# squared error is 29189.855903263626
# mean squared error is 5837.971180652725
# R square is 0.998802471175639
# 7
# 0.8132165237311936
# squared error is 30092.966450316733
# mean squared error is 5015.494408386122
# R square is 0.9990250702089875
# 8
# 0.8128863467440951
# squared error is 31111.415648904822
# mean squared error is 4444.487949843546
# R square is 0.9991639643245239
# 9
# 0.8138003274901351
# squared error is 33317.9571563083
# mean squared error is 4164.744644538538
# R square is 0.9992248081159246
# 10
# 0.814573698836796
# squared error is 35534.56018362004
# mean squared error is 3948.2844648466707
# R square is 0.9992687010306383

# %%
fig,ax = plt.subplots(figsize=(15,9),facecolor = 'white')
#plt.subplot(1,2,1)
plotss = plt.plot(y_cut,ss_cut,'ko', linewidth=1, label = "data points")
plotss = plt.plot(y_cut,stress_fit,'-k', linewidth=1, label = "linear fit")
plt.xlabel('$x/W$')
plt.ylabel('$\sigma_{yy}/\sigma_{yy(boundary)}$')
#plt.xlim([0.66,0.75])
#plt.ylim([0, 13])
plt.rc('axes', titlesize=18) 
plt.rc('xtick', labelsize=18) 
plt.rc('ytick', labelsize=18) 
plt.rc('axes', labelsize=18)

#ax.legend()
plt.legend(loc=2, prop={'size': 18})
plt.legend(loc=2, prop={'size': 18})
plt.title('')
#grids
plt.minorticks_on()
#plt.grid (which='minor', color='g', ls='-.', lw=0.5)
#plt.grid(which='major',color='g', ls='--', lw=0.5)
#################for zooming particular range


plt.show()
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\s'
# <>:6: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Ayan Basu\AppData\Local\Temp\ipykernel_8756\2667237753.py:6: SyntaxWarning: invalid escape sequence '\s'
#   plt.ylabel('$\sigma_{yy}/\sigma_{yy(boundary)}$')

# %%
array = [pos_x,sig_yy,normalized_x,normalized_stress]

df = pd.DataFrame(array).T
df.to_excel(excel_writer = "nd_0.80.xlsx")
