# %%
import matplotlib as mpl
mpl.rcParams['font.family']='serif'
mpl.rcParams['mathtext.fontset']='cm'
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from matplotlib.pyplot import legend,gca
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes
from mpl_toolkits.axes_grid1.inset_locator import mark_inset

# %%
dt = pd.read_excel (r'stress_data_95.xlsx')
mat = dt.to_numpy()
new_mat=np.transpose(mat)

# %%
pos_x = new_mat[1]
pos_x = pos_x/10
pos_x
# Out:
# array([144.981, 145.524, 146.067, 146.61 , 147.153, 147.696, 148.239,
#        148.782, 149.325, 149.868, 150.411, 150.954, 151.497, 152.04 ,
#        152.583, 153.126, 153.669, 154.212, 154.755, 155.298, 155.841,
#        156.384, 156.927, 157.47 , 158.013, 158.556, 159.099, 159.642,
#        160.185, 160.728, 161.271, 161.814, 162.357, 162.9  , 163.443,
#        163.986, 164.529, 165.072, 165.615, 166.158, 166.701, 167.244,
#        167.787, 168.33 , 168.873, 169.416, 169.959, 170.502, 171.045,
#        171.588, 172.131, 172.674, 173.217, 173.76 , 174.303, 174.846,
#        175.389, 175.932, 176.475, 177.018, 177.561, 178.104, 178.647,
#        179.19 , 179.733, 180.276, 180.819, 181.362, 181.905, 182.448,
#        182.991, 183.534, 184.077, 184.62 , 185.163, 185.706, 186.249,
#        186.792, 187.335, 187.878, 188.421, 188.964, 189.507, 190.05 ,
#        190.593, 191.136, 191.679, 192.222, 192.765, 193.308, 193.851,
# ...

# %%
sig_yy =new_mat[12]
sig_yy
# Out:
# array([10.94999624,  8.16145387,  5.93807283,  4.98265343,  4.41360276,
#         4.02939125,  3.73888664,  3.52467183,  3.35025068,  3.21804045,
#         3.09184741,  3.0004397 ,  2.91080317,  2.85626761,  2.76217868,
#         2.73605304,  2.6606764 ,  2.65760265,  2.59816114,  2.55459663,
#         2.51441697,  2.50380678,  2.48866612,  2.45345259,  2.43947419,
#         2.40616095,  2.37272087,  2.32777686,  2.2984464 ,  2.25981568,
#         2.26038209,  2.24449085,  2.22285557,  2.21371692,  2.21045242,
#         2.19386193,  2.18376658,  2.18262693,  2.17838689,  2.18263727,
#         2.19061601,  2.18959742,  2.19472299,  2.19240478,  2.18216926,
#         2.1855812 ,  2.17605184,  2.16903982,  2.17180664,  2.15961631,
#         2.16230795,  2.15391971,  2.15045388,  2.1470173 ,  2.13987023,
#         2.13898431,  2.13308232,  2.12909379,  2.12776752,  2.12183672,
#         2.11869014,  2.11876002,  2.11404796,  2.11079206,  2.11396115,
# ...

# %%
fig,ax = plt.subplots(figsize=(15,9),facecolor = 'white')
#plt.subplot(1,2,1)
plotss = plt.plot(pos_x,sig_yy,'--ko', linewidth=1, label = "$\sigma_{yy}$ curve obtained from MD")
plt.xlabel('X co-ordinate of atom position (nm)')
plt.ylabel('$\sigma_{yy}$ (GPa)')
#plt.xlim([0.66,0.75])
#plt.ylim([0, 13])
plt.rc('axes', titlesize=18) 
plt.rc('xtick', labelsize=18) 
plt.rc('ytick', labelsize=18) 
plt.rc('axes', labelsize=18)

#ax.legend()
plt.legend(loc=1, prop={'size': 18})
plt.legend(loc=1, prop={'size': 18})
plt.title('')
#grids
plt.minorticks_on()
#plt.grid (which='minor', color='g', ls='-.', lw=0.5)
#plt.grid(which='major',color='g', ls='--', lw=0.5)
#################for zooming particular range


#plt.show()
plt.savefig('mid_95_s_local.pdf',dpi = 1200)

# %%
boundary_stress = 0.930303473

total_width = 217.2

# %%
normalized_stress = sig_yy/boundary_stress
normalized_x = pos_x/total_width

# %%
fig,ax = plt.subplots(figsize=(15,9),facecolor = 'white')
#plt.subplot(1,2,1)
plotss = plt.plot(normalized_x,normalized_stress,'--ko', linewidth=1, label = "normalized data for edge crack")
plt.xlabel('$x/W$')
plt.ylabel('$\sigma_{yy}/\sigma_{yy(boundary)}$')
#plt.xlim([0.66,0.75])
#plt.ylim([0, 13])
plt.rc('axes', titlesize=18) 
plt.rc('xtick', labelsize=18) 
plt.rc('ytick', labelsize=18) 
plt.rc('axes', labelsize=18)

#ax.legend()
plt.legend(loc=1, prop={'size': 18})
plt.legend(loc=1, prop={'size': 18})
plt.title('')
#grids
plt.minorticks_on()
#plt.grid (which='minor', color='g', ls='-.', lw=0.5)
#plt.grid(which='major',color='g', ls='--', lw=0.5)
#################for zooming particular range


#plt.show()
plt.savefig('mid_95_s_local_normalized.pdf',dpi = 1200)

# %%
xx = pos_x-(2*total_width/3)
xx*10
# Out:
# array([  1.81,   7.24,  12.67,  18.1 ,  23.53,  28.96,  34.39,  39.82,
#         45.25,  50.68,  56.11,  61.54,  66.97,  72.4 ,  77.83,  83.26,
#         88.69,  94.12,  99.55, 104.98, 110.41, 115.84, 121.27, 126.7 ,
#        132.13, 137.56, 142.99, 148.42, 153.85, 159.28, 164.71, 170.14,
#        175.57, 181.  , 186.43, 191.86, 197.29, 202.72, 208.15, 213.58,
#        219.01, 224.44, 229.87, 235.3 , 240.73, 246.16, 251.59, 257.02,
#        262.45, 267.88, 273.31, 278.74, 284.17, 289.6 , 295.03, 300.46,
#        305.89, 311.32, 316.75, 322.18, 327.61, 333.04, 338.47, 343.9 ,
#        349.33, 354.76, 360.19, 365.62, 371.05, 376.48, 381.91, 387.34,
#        392.77, 398.2 , 403.63, 409.06, 414.49, 419.92, 425.35, 430.78,
#        436.21, 441.64, 447.07, 452.5 , 457.93, 463.36, 468.79, 474.22,
#        479.65, 485.08, 490.51, 495.94, 501.37, 506.8 , 512.23, 517.66,
#        523.09, 528.52, 533.95, 539.38, 544.81, 550.24, 555.67, 561.1 ,
# ...

# %%
stresses_mpa = sig_yy*1000
xx_m = xx*10**(-9)
stresses_mpa
# Out:
# array([10949.99624491,  8161.45386595,  5938.07282866,  4982.65342525,
#         4413.60275558,  4029.39125134,  3738.88663777,  3524.67182539,
#         3350.25067832,  3218.04044623,  3091.84741078,  3000.43969861,
#         2910.80317075,  2856.2676129 ,  2762.1786765 ,  2736.05304091,
#         2660.67640372,  2657.60264941,  2598.16113543,  2554.59663381,
#         2514.41697397,  2503.8067826 ,  2488.66612269,  2453.45258686,
#         2439.47418596,  2406.16095451,  2372.72087225,  2327.77685586,
#         2298.44639886,  2259.81568392,  2260.38209272,  2244.49085256,
#         2222.85556642,  2213.71692084,  2210.45242377,  2193.86192782,
#         2183.76658133,  2182.62693239,  2178.38688747,  2182.63727278,
#         2190.61600679,  2189.59741864,  2194.72299469,  2192.4047765 ,
#         2182.16925915,  2185.5811999 ,  2176.05184335,  2169.03981608,
#         2171.80663954,  2159.61631155,  2162.30794681,  2153.9197098 ,
# ...

# %%
Y_inv = np.sqrt(2*np.pi*xx_m)
YY = 1/Y_inv
YY
# Out:
# array([29653.14617129, 14826.57308564, 11207.8357657 ,  9377.14816912,
#         8224.30299995,  7413.28654282,  6802.89829046,  6322.07200592,
#         5930.62923426,  5603.91788285,  5325.86227414,  5085.4726134 ,
#         4874.94720098,  4688.57408456,  4522.06239699,  4372.11787764,
#         4236.16373876,  4112.15149998,  3998.42941406,  3893.64884682,
#         3796.69631597,  3706.64327141,  3622.70839116,  3544.22886607,
#         3470.63824586,  3401.44914523,  3336.23959817,  3274.64218462,
#         3216.33528735,  3161.03600296,  3108.49434925,  3058.48849795,
#         3010.82082492,  2965.31461713,  2921.81131123,  2880.16816506,
#         2840.25628424,  2801.95894142,  2765.17013842,  2729.79337061,
#         2695.74056103,  2662.93113707,  2631.29122798,  2600.75296472,
#         2571.25386729,  2542.7363067 ,  2515.14703127,  2488.43674818,
#         2462.55975297,  2437.47360049,  2413.13881204,  2389.51861404,
# ...

# %%
#remove the entry of the first atom
YY = YY[1:]
stresses_mpa = stresses_mpa[1:]

# %%
fig,ax = plt.subplots(figsize=(15,9),facecolor = 'white')
#plt.subplot(1,2,1)
plotss = plt.plot(YY,stresses_mpa,'--ko', linewidth=1, label = "normalized data for edge crack")
plt.xlabel('$x/W$')
plt.ylabel('$\sigma_{yy}/\sigma_{yy(boundary)}$')
#plt.xlim([0.66,0.75])
#plt.ylim([0, 13])
plt.rc('axes', titlesize=18) 
plt.rc('xtick', labelsize=18) 
plt.rc('ytick', labelsize=18) 
plt.rc('axes', labelsize=18)

#ax.legend()
plt.legend(loc=1, prop={'size': 18})
plt.legend(loc=1, prop={'size': 18})
plt.title('')
#grids
plt.minorticks_on()
#plt.grid (which='minor', color='g', ls='-.', lw=0.5)
#plt.grid(which='major',color='g', ls='--', lw=0.5)
#################for zooming particular range


plt.show()
#plt.savefig('edge_s_local_normalized.pdf',dpi = 1200)

# %%
ss_cut =stresses_mpa[1:10]
y_cut = YY[1:10]

# %%
m_x = np.mean(y_cut)
m_y = np.mean(ss_cut)
kic = m_y/m_x
kic
# Out:
# 0.5480824511940623

# %%
b_0 = 0     
b_1 = 0.5480824511940623

stress_fit = b_1 * y_cut + b_0 
error = ss_cut - stress_fit
n_1 = np.size(y_cut)
ss_mean = np.mean(ss_cut)
se = np.sum(error**2)
print('squared error is', se)
mse = se/n_1 
print('mean squared error is', mse)
SSt = np.sum((ss_cut - ss_mean)**2)
R2 = 1- (se/SSt)
print('R square is', R2)
# Out:
# squared error is 141470.40349374892
# mean squared error is 15718.933721527657
# R square is 0.979896146700319

# %%
fig,ax = plt.subplots(figsize=(15,9),facecolor = 'white')
#plt.subplot(1,2,1)
plotss = plt.plot(y_cut,ss_cut,'ko', linewidth=1, label = "data points")
plotss = plt.plot(y_cut,stress_fit,'-k', linewidth=1, label = "linear fit")
plt.xlabel('$x/W$')
plt.ylabel('$\sigma_{yy}/\sigma_{yy(boundary)}$')
#plt.xlim([0.66,0.75])
#plt.ylim([0, 13])
plt.rc('axes', titlesize=18) 
plt.rc('xtick', labelsize=18) 
plt.rc('ytick', labelsize=18) 
plt.rc('axes', labelsize=18)

#ax.legend()
plt.legend(loc=2, prop={'size': 18})
plt.legend(loc=2, prop={'size': 18})
plt.title('')
#grids
plt.minorticks_on()
#plt.grid (which='minor', color='g', ls='-.', lw=0.5)
#plt.grid(which='major',color='g', ls='--', lw=0.5)
#################for zooming particular range


plt.show()

# %%
array_new = [y_cut,ss_cut,stress_fit]

df = pd.DataFrame(array_new).T
df.to_excel(excel_writer = "new_95.xlsx")

# %%
for i in range(2,11):
    print(i+1)
    ss_cut =stresses_mpa[4:i]
    y_cut = YY[4:i]

    m_x = np.mean(y_cut)
    m_y = np.mean(ss_cut)
    kic = m_y/m_x
    print(kic)

    b_0 = 0     
    b_1 = kic

    stress_fit = b_1 * y_cut + b_0 
    error = ss_cut - stress_fit
    n_1 = np.size(y_cut)
    ss_mean = np.mean(ss_cut)
    se = np.sum(error**2)
    print('squared error is', se)
    mse = se/n_1 
    print('mean squared error is', mse)
    SSt = np.sum((ss_cut - ss_mean)**2)
    R2 = 1- (se/SSt)
    print('R square is', R2)

# %%
fig,ax = plt.subplots(figsize=(15,9),facecolor = 'white')
#plt.subplot(1,2,1)
plotss = plt.plot(y_cut,ss_cut,'ko', linewidth=1, label = "data points")
plotss = plt.plot(y_cut,stress_fit,'-k', linewidth=1, label = "linear fit")
plt.xlabel('$x/W$')
plt.ylabel('$\sigma_{yy}/\sigma_{yy(boundary)}$')
#plt.xlim([0.66,0.75])
#plt.ylim([0, 13])
plt.rc('axes', titlesize=18) 
plt.rc('xtick', labelsize=18) 
plt.rc('ytick', labelsize=18) 
plt.rc('axes', labelsize=18)

#ax.legend()
plt.legend(loc=2, prop={'size': 18})
plt.legend(loc=2, prop={'size': 18})
plt.title('')
#grids
plt.minorticks_on()
#plt.grid (which='minor', color='g', ls='-.', lw=0.5)
#plt.grid(which='major',color='g', ls='--', lw=0.5)
#################for zooming particular range


plt.show()

# %%
array = [pos_x,sig_yy,normalized_x,normalized_stress]

df = pd.DataFrame(array).T
df.to_excel(excel_writer = "nd_0.95.xlsx")
