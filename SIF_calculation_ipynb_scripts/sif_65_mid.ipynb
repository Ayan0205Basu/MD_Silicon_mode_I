# %%
import matplotlib as mpl
mpl.rcParams['font.family']='serif'
mpl.rcParams['mathtext.fontset']='cm'
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
dt = pd.read_excel (r'stress_data_65.xlsx')
mat = dt.to_numpy()
new_mat=np.transpose(mat)

# %%
pos_x = new_mat[1]
pos_x = pos_x/10
pos_x
# Out:
# array([144.981, 145.524, 146.067, 146.61 , 147.153, 147.696, 148.239,
#        148.782, 149.325, 149.868, 150.411, 150.954, 151.497, 152.04 ,
#        152.583, 153.126, 153.669, 154.212, 154.755, 155.298, 155.841,
#        156.384, 156.927, 157.47 , 158.013, 158.556, 159.099, 159.642,
#        160.185, 160.728, 161.271, 161.814, 162.357, 162.9  , 163.443,
#        163.986, 164.529, 165.072, 165.615, 166.158, 166.701, 167.244,
#        167.787, 168.33 , 168.873, 169.416, 169.959, 170.502, 171.045,
#        171.588, 172.131, 172.674, 173.217, 173.76 , 174.303, 174.846,
#        175.389, 175.932, 176.475, 177.018, 177.561, 178.104, 178.647,
#        179.19 , 179.733, 180.276, 180.819, 181.362, 181.905, 182.448,
#        182.991, 183.534, 184.077, 184.62 , 185.163, 185.706, 186.249,
#        186.792, 187.335, 187.878, 188.421, 188.964, 189.507, 190.05 ,
#        190.593, 191.136, 191.679, 192.222, 192.765, 193.308, 193.851,
#        194.394, 194.937, 195.48 , 196.023, 196.566, 197.109, 197.652,
#        198.195, 198.738, 199.281, 199.824, 200.367, 200.91 , 201.453,
#        201.996, 202.539, 203.082, 203.625, 204.168, 204.711, 205.254,
#        205.797, 206.34 , 206.883, 207.426, 207.969, 208.512, 209.055,
#        209.598, 210.141, 210.684, 211.227, 211.77 , 212.313, 212.856,
#        213.399, 213.942, 214.485, 215.028, 215.571, 216.114, 216.657])

# %%
sig_yy =new_mat[11]
sig_yy
# Out:
# array([29.97516377, 21.76951043, 15.46705754, 11.18559043,  9.7778675 ,
#         7.92303888,  7.18510529,  6.72913937,  6.1267938 ,  5.95391892,
#         5.91436841,  5.38057226,  5.24654304,  5.1743447 ,  4.98846102,
#         4.79049637,  4.69208903,  4.52097462,  4.43980355,  4.28306087,
#         4.17655342,  4.12404165,  4.05259672,  3.99354316,  3.87131323,
#         3.78924974,  3.85870135,  3.70682346,  3.63417426,  3.70012219,
#         3.61420872,  3.6379897 ,  3.63127909,  3.63531764,  3.6662561 ,
#         3.68689731,  3.7106083 ,  3.68409722,  3.695743  ,  3.67801746,
#         3.63924914,  3.69730884,  3.64837252,  3.70365999,  3.68304798,
#         3.69154184,  3.67236192,  3.67135054,  3.65291195,  3.66403549,
#         3.60378483,  3.67510641,  3.65952193,  3.68251044,  3.65163408,
#         3.67223961,  3.68359885,  3.69185351,  3.68776918,  3.68503186,
#         3.70578978,  3.67996585,  3.73959267,  3.72072295,  3.73406341,
#         3.71950909,  3.7302844 ,  3.74287787,  3.79586222,  3.74104275,
#         3.7764685 ,  3.7351375 ,  3.73820677,  3.73864954,  3.73535188,
#         3.75297307,  3.7479702 ,  3.75124943,  3.70385918,  3.71382359,
#         3.69829877,  3.72881796,  3.7118457 ,  3.6941019 ,  3.71128546,
#         3.72662911,  3.6841811 ,  3.62758971,  3.61122931,  3.57896075,
#         3.7377931 ,  3.75081827,  3.74862692,  3.7457781 ,  3.74649365,
#         3.72185344,  3.7439112 ,  3.72127991,  3.74071361,  3.73887337,
#         3.73739015,  3.73604999,  3.73365673,  3.72858954,  3.71071449,
#         3.72280239,  3.7233741 ,  3.6993584 ,  3.71936085,  3.71513229,
#         3.71361652,  3.70806058,  3.70430324,  3.68039067,  3.67379768,
#         3.67101738,  3.67000719,  3.66952444,  3.66951832,  3.66101294,
#         3.65593235,  3.65991248,  3.64516027,  3.64718087,  3.64408727,
#         3.59971056,  3.63167469,  3.62539715,  3.61868897,  3.60984923,
#         3.60415837,  3.58805042,  3.51792439])

# %%
fig,ax = plt.subplots(figsize=(15,9),facecolor = 'white')
#plt.subplot(1,2,1)
plotss = plt.plot(pos_x,sig_yy,'--ko', linewidth=1, label = "$\sigma_{yy}$ curve obtained from MD")
plt.xlabel('X co-ordinate of atom position (nm)')
plt.ylabel('$\sigma_{yy}$ (GPa)')
#plt.xlim([0.66,0.75])
#plt.ylim([0, 13])
plt.rc('axes', titlesize=18) 
plt.rc('xtick', labelsize=18) 
plt.rc('ytick', labelsize=18) 
plt.rc('axes', labelsize=18)

#ax.legend()
plt.legend(loc=1, prop={'size': 18})
plt.legend(loc=1, prop={'size': 18})
plt.title('')
#grids
plt.minorticks_on()
#plt.grid (which='minor', color='g', ls='-.', lw=0.5)
#plt.grid(which='major',color='g', ls='--', lw=0.5)
#################for zooming particular range


#plt.show()
plt.savefig('mid_65_s_local.pdf',dpi = 1200)

# %%
boundary_stress = 3.06668324822
total_width = 217.2

# %%
normalized_stress = sig_yy/boundary_stress
normalized_x = pos_x/total_width

# %%
fig,ax = plt.subplots(figsize=(15,9),facecolor = 'white')
#plt.subplot(1,2,1)
plotss = plt.plot(normalized_x,normalized_stress,'--ko', linewidth=1, label = "normalized data for edge crack")
plt.xlabel('$x/W$')
plt.ylabel('$\sigma_{yy}/\sigma_{yy(boundary)}$')
#plt.xlim([0.66,0.75])
#plt.ylim([0, 13])
plt.rc('axes', titlesize=18) 
plt.rc('xtick', labelsize=18) 
plt.rc('ytick', labelsize=18) 
plt.rc('axes', labelsize=18)

#ax.legend()
plt.legend(loc=1, prop={'size': 18})
plt.legend(loc=1, prop={'size': 18})
plt.title('')
#grids
plt.minorticks_on()
#plt.grid (which='minor', color='g', ls='-.', lw=0.5)
#plt.grid(which='major',color='g', ls='--', lw=0.5)
#################for zooming particular range


#plt.show()
plt.savefig('mid_65_s_local_normalized.pdf',dpi = 1200)

# %%
xx = pos_x-(2*total_width/3)
xx
# Out:
# array([ 0.181,  0.724,  1.267,  1.81 ,  2.353,  2.896,  3.439,  3.982,
#         4.525,  5.068,  5.611,  6.154,  6.697,  7.24 ,  7.783,  8.326,
#         8.869,  9.412,  9.955, 10.498, 11.041, 11.584, 12.127, 12.67 ,
#        13.213, 13.756, 14.299, 14.842, 15.385, 15.928, 16.471, 17.014,
#        17.557, 18.1  , 18.643, 19.186, 19.729, 20.272, 20.815, 21.358,
#        21.901, 22.444, 22.987, 23.53 , 24.073, 24.616, 25.159, 25.702,
#        26.245, 26.788, 27.331, 27.874, 28.417, 28.96 , 29.503, 30.046,
#        30.589, 31.132, 31.675, 32.218, 32.761, 33.304, 33.847, 34.39 ,
#        34.933, 35.476, 36.019, 36.562, 37.105, 37.648, 38.191, 38.734,
#        39.277, 39.82 , 40.363, 40.906, 41.449, 41.992, 42.535, 43.078,
#        43.621, 44.164, 44.707, 45.25 , 45.793, 46.336, 46.879, 47.422,
#        47.965, 48.508, 49.051, 49.594, 50.137, 50.68 , 51.223, 51.766,
#        52.309, 52.852, 53.395, 53.938, 54.481, 55.024, 55.567, 56.11 ,
#        56.653, 57.196, 57.739, 58.282, 58.825, 59.368, 59.911, 60.454,
#        60.997, 61.54 , 62.083, 62.626, 63.169, 63.712, 64.255, 64.798,
#        65.341, 65.884, 66.427, 66.97 , 67.513, 68.056, 68.599, 69.142,
#        69.685, 70.228, 70.771, 71.314, 71.857])

# %%
stresses_mpa = sig_yy*1000
xx_m = xx*10**(-9)
stresses_mpa
# Out:
# array([29975.16377072, 21769.51043482, 15467.05754288, 11185.59043304,
#         9777.86749827,  7923.0388775 ,  7185.10529329,  6729.13937382,
#         6126.79379758,  5953.91892038,  5914.36840547,  5380.57226087,
#         5246.54304209,  5174.34469696,  4988.4610215 ,  4790.49636984,
#         4692.08903201,  4520.97462279,  4439.80354952,  4283.06087409,
#         4176.5534239 ,  4124.04164773,  4052.59671936,  3993.54315918,
#         3871.31322818,  3789.24974429,  3858.70135208,  3706.82345656,
#         3634.17425852,  3700.12219306,  3614.20871627,  3637.98969612,
#         3631.27908578,  3635.31763928,  3666.25610189,  3686.89730761,
#         3710.60829934,  3684.09722414,  3695.74300003,  3678.01745961,
#         3639.24913603,  3697.30883738,  3648.37251574,  3703.65998768,
#         3683.04798029,  3691.54183682,  3672.36192391,  3671.3505361 ,
#         3652.91195006,  3664.03549118,  3603.78483045,  3675.1064101 ,
#         3659.52192638,  3682.51043697,  3651.634083  ,  3672.23960577,
#         3683.59885438,  3691.85350816,  3687.76918055,  3685.03186469,
#         3705.78978025,  3679.96584514,  3739.59266808,  3720.72295093,
#         3734.06340677,  3719.50908529,  3730.28439502,  3742.8778688 ,
#         3795.86221743,  3741.04275121,  3776.46850385,  3735.13750281,
#         3738.20676515,  3738.64954089,  3735.35188259,  3752.97306685,
#         3747.97019951,  3751.24942737,  3703.85918427,  3713.82358965,
#         3698.29877338,  3728.81795664,  3711.84569871,  3694.10190032,
#         3711.28545724,  3726.62910959,  3684.18109785,  3627.58970696,
#         3611.22930876,  3578.96075218,  3737.79310322,  3750.81826585,
#         3748.62692383,  3745.77810085,  3746.49365007,  3721.85343521,
#         3743.91119561,  3721.27990968,  3740.71360985,  3738.87337416,
#         3737.39014848,  3736.04999118,  3733.656727  ,  3728.58954281,
#         3710.7144919 ,  3722.80238658,  3723.37409783,  3699.35839575,
#         3719.36084579,  3715.1322887 ,  3713.61652091,  3708.06057764,
#         3704.3032438 ,  3680.39066995,  3673.79768362,  3671.01738066,
#         3670.00719067,  3669.52444268,  3669.51831742,  3661.01294019,
#         3655.93235443,  3659.91247866,  3645.16026703,  3647.18086994,
#         3644.08726834,  3599.71056336,  3631.6746881 ,  3625.39715297,
#         3618.68897267,  3609.8492263 ,  3604.15836563,  3588.05042394,
#         3517.92439256])

# %%
Y_inv = np.sqrt(2*np.pi*xx_m)
YY = 1/Y_inv
YY
# Out:
# array([29653.14617129, 14826.57308564, 11207.8357657 ,  9377.14816912,
#         8224.30299995,  7413.28654282,  6802.89829046,  6322.07200592,
#         5930.62923426,  5603.91788285,  5325.86227414,  5085.4726134 ,
#         4874.94720098,  4688.57408456,  4522.06239699,  4372.11787764,
#         4236.16373876,  4112.15149998,  3998.42941406,  3893.64884682,
#         3796.69631597,  3706.64327141,  3622.70839116,  3544.22886607,
#         3470.63824586,  3401.44914523,  3336.23959817,  3274.64218462,
#         3216.33528735,  3161.03600296,  3108.49434925,  3058.48849795,
#         3010.82082492,  2965.31461713,  2921.81131123,  2880.16816506,
#         2840.25628424,  2801.95894142,  2765.17013842,  2729.79337061,
#         2695.74056103,  2662.93113707,  2631.29122798,  2600.75296472,
#         2571.25386729,  2542.7363067 ,  2515.14703127,  2488.43674818,
#         2462.55975297,  2437.47360049,  2413.13881204,  2389.51861404,
#         2366.57870425,  2344.28704228,  2322.61366137,  2301.53049897,
#         2281.01124395,  2261.03119849,  2241.56715314,  2222.59727338,
#         2204.10099669,  2186.05893882,  2168.45280837,  2151.26532883,
#         2134.48016733,  2118.08186938,  2102.05579902,  2086.38808396,
#         2071.06556509,  2056.07574999,  2041.40677015,  2027.04734147,
#         2012.98672776,  1999.21470703,  1985.7215402 ,  1972.49794223,
#         1959.5350552 ,  1946.82442341,  1934.35797019,  1922.12797633,
#         1910.12705999,  1898.34815798,  1886.78450831,  1875.42963382,
#         1864.27732701,  1853.32163571,  1842.55684977,  1831.97748854,
#         1821.57828918,  1811.35419558,  1801.30034811,  1791.41207388,
#         1781.68487761,  1772.11443303,  1762.69657486,  1753.42729112,
#         1744.30271596,  1735.31912293,  1726.47291855,  1717.76063628,
#         1709.17893079,  1700.72457261,  1692.39444299,  1684.18552906,
#         1676.09491928,  1668.11979909,  1660.25744676,  1652.50522956,
#         1644.86059999,  1637.32109231,  1629.88431915,  1622.5479684 ,
#         1615.3098001 ,  1608.16764368,  1601.1193951 ,  1594.16301436,
#         1587.29652294,  1580.51800148,  1573.8255875 ,  1567.21747327,
#         1560.69190375,  1554.24717462,  1547.88163044,  1541.59366282,
#         1535.38170875,  1529.24424897,  1523.17980638,  1517.18694456,
#         1511.26426635,  1505.41041246,  1499.62406018,  1493.90392213,
#         1488.24874503])

# %%
#remove the entry of the first atom
YY = YY[1:]
stresses_mpa = stresses_mpa[1:]

# %%
fig,ax = plt.subplots(figsize=(15,9),facecolor = 'white')
#plt.subplot(1,2,1)
plotss = plt.plot(YY,stresses_mpa,'--ko', linewidth=1, label = "normalized data for edge crack")
plt.xlabel('$x/W$')
plt.ylabel('$\sigma_{yy}/\sigma_{yy(boundary)}$')
#plt.xlim([0.66,0.75])
#plt.ylim([0, 13])
plt.rc('axes', titlesize=18) 
plt.rc('xtick', labelsize=18) 
plt.rc('ytick', labelsize=18) 
plt.rc('axes', labelsize=18)

#ax.legend()
plt.legend(loc=1, prop={'size': 18})
plt.legend(loc=1, prop={'size': 18})
plt.title('')
#grids
plt.minorticks_on()
#plt.grid (which='minor', color='g', ls='-.', lw=0.5)
#plt.grid(which='major',color='g', ls='--', lw=0.5)
#################for zooming particular range


plt.show()
#plt.savefig('edge_s_local_normalized.pdf',dpi = 1200)

# %%
ss_cut =stresses_mpa[4:5]
y_cut = YY[4:5]

# %%
m_x = np.mean(y_cut)
m_y = np.mean(ss_cut)
kic = m_y/m_x
kic
# Out:
# 1.0687619899393013

# %%
b_0 = 0     
b_1 = 1.1807639157422771

# %%
stress_fit = b_1 * y_cut + b_0 
error = ss_cut - stress_fit
n_1 = np.size(y_cut)
ss_mean = np.mean(ss_cut)
se = np.sum(error**2)
print('squared error is', se)
mse = se/n_1 
print('mean squared error is', mse)
SSt = np.sum((ss_cut - ss_mean)**2)
R2 = 1- (se/SSt)
print('R square is', R2)
# Out:
# squared error is 18171702.056041673
# mean squared error is 18171702.056041673
# R square is -inf
# C:\Users\AYANBA~1\AppData\Local\Temp/ipykernel_19296/2174593048.py:10: RuntimeWarning: divide by zero encountered in double_scalars
#   R2 = 1- (se/SSt)

# %%
for i in range(6,44):
    print(i+1)
    ss_cut =stresses_mpa[4:i]
    y_cut = YY[4:i]

    m_x = np.mean(y_cut)
    m_y = np.mean(ss_cut)
    kic = m_y/m_x
    print(kic)

    b_0 = 0     
    b_1 = kic

    stress_fit = b_1 * y_cut + b_0 
    error = ss_cut - stress_fit
    n_1 = np.size(y_cut)
    ss_mean = np.mean(ss_cut)
    se = np.sum(error**2)
    print('squared error is', se)
    mse = se/n_1 
    print('mean squared error is', mse)
    SSt = np.sum((ss_cut - ss_mean)**2)
    R2 = 1- (se/SSt)
    print('R square is', R2)
# Out:
# 7
# 1.0627425253660256
# squared error is 3982.605557253863
# mean squared error is 1991.3027786269315
# R square is 0.9853727481523515
# 8
# 1.0632491216556827
# squared error is 4032.856373179091
# mean squared error is 1344.2854577263636
# R square is 0.9944447109608966
# 9
# 1.0564886359249177
# squared error is 30055.905622528186
# mean squared error is 7513.976405632046
# R square is 0.9825438706179637
# 10
# 1.0575313685945753
# squared error is 30691.119264724337
# mean squared error is 6138.223852944868
# R square is 0.9881146216396705
# 11
# 1.0650744714425822
# squared error is 99181.41960560487
# mean squared error is 16530.236600934146
# R square is 0.9691205786064367
# 12
# 1.064230985006033
# squared error is 100082.30047439627
# mean squared error is 14297.471496342323
# R square is 0.9780939783161233
# 13
# 1.0654656621381962
# squared error is 103521.28678459808
# mean squared error is 12940.16084807476
# R square is 0.9823191294465575
# 14
# 1.0689015515716482
# squared error is 134640.5367306815
# mean squared error is 14960.059636742388
# R square is 0.9807552643803629
# 15
# 1.0716383779541072
# squared error is 159444.59147223333
# mean squared error is 15944.459147223333
# R square is 0.9807371537487636
# 16
# 1.0733640734453826
# squared error is 172028.2584519443
# mean squared error is 15638.932586540392
# R square is 0.982351709087428
# 17
# 1.0755909453403354
# squared error is 195468.46582952066
# mean squared error is 16289.038819126721
# R square is 0.9825322886975423
# 18
# 1.0770050236121143
# squared error is 207351.09932450275
# mean squared error is 15950.084563423288
# R square is 0.9838023650460758
# 19
# 1.078826248348735
# squared error is 228466.94027629177
# mean squared error is 16319.06716259227
# R square is 0.9841035130876359
# 20
# 1.0798950214602716
# squared error is 237768.9177041474
# mean squared error is 15851.261180276493
# R square is 0.9852407874907286
# 21
# 1.0808399582986397
# squared error is 246082.4950807772
# mean squared error is 15380.155942548576
# R square is 0.986248771823628
# 22
# 1.0822304370304
# squared error is 263767.5075136797
# mean squared error is 15515.735736098804
# R square is 0.9865432861901633
# 23
# 1.0837251035684592
# squared error is 285798.25542271987
# mean squared error is 15877.680856817771
# R square is 0.9865780391478232
# 24
# 1.0853861726343186
# squared error is 314820.18938134785
# mean squared error is 16569.483651649887
# R square is 0.9862836069348898
# 25
# 1.0864806650740138
# squared error is 330120.09386142803
# mean squared error is 16506.0046930714
# R square is 0.9866619958603031
# 26
# 1.0874291725030611
# squared error is 343049.69558024756
# mean squared error is 16335.699789535598
# R square is 0.987097583282375
# 27
# 1.0896903442873018
# squared error is 406364.1053055216
# mean squared error is 18471.095695705528
# R square is 0.9855323805019146
# 28
# 1.0910049771829815
# squared error is 432572.4853150897
# mean squared error is 18807.49936152564
# R square is 0.9854972564556963
# 29
# 1.0921577580138686
# squared error is 454942.11328071874
# mean squared error is 18955.921386696613
# R square is 0.9856057275432949
# 30
# 1.0943756962042888
# squared error is 529728.7978405902
# mean squared error is 21189.15191362361
# R square is 0.9839869909417559
# 31
# 1.0962250740148969
# squared error is 587590.6854528557
# mean squared error is 22599.641748186757
# R square is 0.9830405332501048
# 32
# 1.098644469311478
# squared error is 687072.9923317953
# mean squared error is 25447.147864140567
# R square is 0.9809362229827217
# 33
# 1.101320089182228
# squared error is 814142.0596122707
# mean squared error is 29076.502129009667
# R square is 0.9782024819673283
# 34
# 1.104303853971065
# squared error is 978756.5171018873
# mean squared error is 33750.224727651286
# R square is 0.9746177202314357
# 35
# 1.107772037492747
# squared error is 1208620.0358898991
# mean squared error is 40287.334529663305
# R square is 0.9694997769909451
# 36
# 1.1116000137563777
# squared error is 1500620.171289986
# mean squared error is 48407.10229967697
# R square is 0.9630240270124706
# 37
# 1.1157765184389596
# squared error is 1863290.1467583082
# mean squared error is 58227.81708619713
# R square is 0.9550334309882391
# 38
# 1.1198987398342424
# squared error is 2237663.659395722
# mean squared error is 67807.98967865825
# R square is 0.9470832759608784
# 39
# 1.1242375005336471
# squared error is 2671023.1017067297
# mean squared error is 78559.50299137441
# R square is 0.9379775873849777
# 40
# 1.128563512332205
# squared error is 3124932.060379747
# mean squared error is 89283.77315370705
# R square is 0.9287035585604366
# 41
# 1.1327236007568096
# squared error is 3569554.640549175
# mean squared error is 99154.29557081041
# R square is 0.9199987812905094
# 42
# 1.1373826920290107
# squared error is 4141057.7261656364
# mean squared error is 111920.47908555774
# R square is 0.9085235286556488
# 43
# 1.141788962929793
# squared error is 4682999.76385254
# mean squared error is 123236.83589085632
# R square is 0.8981145028082282
# 44
# 1.146638484785868
# squared error is 5355724.533412835
# mean squared error is 137326.27008750857
# R square is 0.8849132445927121

# %%
fig,ax = plt.subplots(figsize=(15,9),facecolor = 'white')
#plt.subplot(1,2,1)
plotss = plt.plot(y_cut,ss_cut,'ko', linewidth=1, label = "data points")
plotss = plt.plot(y_cut,stress_fit,'-k', linewidth=1, label = "linear fit")
plt.xlabel('$x/W$')
plt.ylabel('$\sigma_{yy}/\sigma_{yy(boundary)}$')
#plt.xlim([0.66,0.75])
#plt.ylim([0, 13])
plt.rc('axes', titlesize=18) 
plt.rc('xtick', labelsize=18) 
plt.rc('ytick', labelsize=18) 
plt.rc('axes', labelsize=18)

#ax.legend()
plt.legend(loc=2, prop={'size': 18})
plt.legend(loc=2, prop={'size': 18})
plt.title('')
#grids
plt.minorticks_on()
#plt.grid (which='minor', color='g', ls='-.', lw=0.5)
#plt.grid(which='major',color='g', ls='--', lw=0.5)
#################for zooming particular range


plt.show()

# %%
array = [pos_x,sig_yy,normalized_x,normalized_stress]

df = pd.DataFrame(array).T
df.to_excel(excel_writer = "nd_0.65.xlsx")
