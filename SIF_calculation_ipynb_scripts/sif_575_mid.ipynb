# %%
import matplotlib as mpl
mpl.rcParams['font.family']='serif'
mpl.rcParams['mathtext.fontset']='cm'
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
dt = pd.read_excel (r'stress_data_575.xlsx')
mat = dt.to_numpy()
new_mat=np.transpose(mat)

# %%
pos_x = new_mat[1]
pos_x = pos_x/10
pos_x
# Out:
# array([144.981, 145.524, 146.067, 146.61 , 147.153, 147.696, 148.239,
#        148.782, 149.325, 149.868, 150.411, 150.954, 151.497, 152.04 ,
#        152.583, 153.126, 153.669, 154.212, 154.755, 155.298, 155.841,
#        156.384, 156.927, 157.47 , 158.013, 158.556, 159.099, 159.642,
#        160.185, 160.728, 161.271, 161.814, 162.357, 162.9  , 163.443,
#        163.986, 164.529, 165.072, 165.615, 166.158, 166.701, 167.244,
#        167.787, 168.33 , 168.873, 169.416, 169.959, 170.502, 171.045,
#        171.588, 172.131, 172.674, 173.217, 173.76 , 174.303, 174.846,
#        175.389, 175.932, 176.475, 177.018, 177.561, 178.104, 178.647,
#        179.19 , 179.733, 180.276, 180.819, 181.362, 181.905, 182.448,
#        182.991, 183.534, 184.077, 184.62 , 185.163, 185.706, 186.249,
#        186.792, 187.335, 187.878, 188.421, 188.964, 189.507, 190.05 ,
#        190.593, 191.136, 191.679, 192.222, 192.765, 193.308, 193.851,
#        194.394, 194.937, 195.48 , 196.023, 196.566, 197.109, 197.652,
#        198.195, 198.738, 199.281, 199.824, 200.367, 200.91 , 201.453,
#        201.996, 202.539, 203.082, 203.625, 204.168, 204.711, 205.254,
#        205.797, 206.34 , 206.883, 207.426, 207.969, 208.512, 209.055,
#        209.598, 210.141, 210.684, 211.227, 211.77 , 212.313, 212.856,
#        213.399, 213.942, 214.485, 215.028, 215.571, 216.114, 216.657])

# %%
sig_yy =new_mat[11]
sig_yy
# Out:
# array([34.34939014, 21.40322586, 14.81422288, 12.00067931, 10.47396189,
#         9.52192168,  8.73757759,  8.15588083,  7.68498804,  7.33567387,
#         6.99712986,  6.69287347,  6.52022467,  6.29028241,  6.15446784,
#         6.01209555,  5.84009759,  5.71490089,  5.59992991,  5.54560978,
#         5.46350474,  5.3689037 ,  5.22647362,  5.29120763,  5.21968978,
#         5.10035588,  5.00320918,  4.91495019,  4.85654312,  4.81885882,
#         4.85454202,  4.80117435,  4.69067377,  4.6668812 ,  4.63204413,
#         4.561087  ,  4.58616306,  4.53692953,  4.54710703,  4.47382747,
#         4.44498716,  4.43510468,  4.40932472,  4.37804839,  4.41269421,
#         4.31175716,  4.3331311 ,  4.32412516,  4.27933569,  4.25288279,
#         4.23328103,  4.16588974,  4.16565818,  4.17740077,  4.18379161,
#         4.19369056,  4.1904292 ,  4.14715674,  4.12721051,  4.06522659,
#         4.09802301,  4.11250494,  4.11350379,  4.07000497,  4.02020873,
#         4.04429162,  4.04753927,  4.03421881,  3.98681456,  4.01683172,
#         3.97271118,  3.94404663,  3.99616907,  3.92855862,  3.95260906,
#         3.99779777,  4.0466337 ,  3.93061391,  3.9088494 ,  3.92313361,
#         3.9264503 ,  3.87616945,  3.86796108,  3.93544021,  3.84681123,
#         3.85046319,  3.82770581,  3.87101969,  3.82560038,  3.82355388,
#         3.77229462,  3.79816465,  3.75203776,  3.79168601,  3.77137568,
#         3.75494381,  3.75087971,  3.80477804,  3.73523946,  3.69360753,
#         3.71128607,  3.64635931,  3.72617059,  3.70557586,  3.65344568,
#         3.7145176 ,  3.68782072,  3.63406194,  3.6174528 ,  3.64860088,
#         3.62981033,  3.65891756,  3.57484505,  3.56562026,  3.60429771,
#         3.62150518,  3.56955876,  3.51268248,  3.53543707,  3.53117148,
#         3.56951444,  3.54548153,  3.52143232,  3.50593847,  3.43599683,
#         3.49833801,  3.46502687,  3.40586397,  3.47068937,  3.43469379,
#         3.37200879,  3.42635487,  3.34375079])

# %%
fig,ax = plt.subplots(figsize=(15,9),facecolor = 'white')
#plt.subplot(1,2,1)
plotss = plt.plot(pos_x,sig_yy,'--ko', linewidth=1, label = "$\sigma_{yy}$ curve obtained from MD")
plt.xlabel('X co-ordinate of atom position (nm)')
plt.ylabel('$\sigma_{yy}$ (GPa)')
#plt.xlim([0.66,0.75])
#plt.ylim([0, 13])
plt.rc('axes', titlesize=18) 
plt.rc('xtick', labelsize=18) 
plt.rc('ytick', labelsize=18) 
plt.rc('axes', labelsize=18)

#ax.legend()
plt.legend(loc=1, prop={'size': 18})
plt.legend(loc=1, prop={'size': 18})
plt.title('')
#grids
plt.minorticks_on()
#plt.grid (which='minor', color='g', ls='-.', lw=0.5)
#plt.grid(which='major',color='g', ls='--', lw=0.5)
#################for zooming particular range


#plt.show()
plt.savefig('mid_575_s_local.pdf',dpi = 1200)

# %%
boundary_stress = 3.29015562
total_width = 217.2

# %%
normalized_stress = sig_yy/boundary_stress
normalized_x = pos_x/total_width

# %%
fig,ax = plt.subplots(figsize=(15,9),facecolor = 'white')
#plt.subplot(1,2,1)
plotss = plt.plot(normalized_x,normalized_stress,'--ko', linewidth=1, label = "normalized data for edge crack")
plt.xlabel('$x/W$')
plt.ylabel('$\sigma_{yy}/\sigma_{yy(boundary)}$')
#plt.xlim([0.66,0.75])
#plt.ylim([0, 13])
plt.rc('axes', titlesize=18) 
plt.rc('xtick', labelsize=18) 
plt.rc('ytick', labelsize=18) 
plt.rc('axes', labelsize=18)

#ax.legend()
plt.legend(loc=1, prop={'size': 18})
plt.legend(loc=1, prop={'size': 18})
plt.title('')
#grids
plt.minorticks_on()
#plt.grid (which='minor', color='g', ls='-.', lw=0.5)
#plt.grid(which='major',color='g', ls='--', lw=0.5)
#################for zooming particular range


#plt.show()
plt.savefig('mid_575_s_local_normalized.pdf',dpi = 1200)

# %%
xx = pos_x-(2*total_width/3)
xx
# Out:
# array([ 0.181,  0.724,  1.267,  1.81 ,  2.353,  2.896,  3.439,  3.982,
#         4.525,  5.068,  5.611,  6.154,  6.697,  7.24 ,  7.783,  8.326,
#         8.869,  9.412,  9.955, 10.498, 11.041, 11.584, 12.127, 12.67 ,
#        13.213, 13.756, 14.299, 14.842, 15.385, 15.928, 16.471, 17.014,
#        17.557, 18.1  , 18.643, 19.186, 19.729, 20.272, 20.815, 21.358,
#        21.901, 22.444, 22.987, 23.53 , 24.073, 24.616, 25.159, 25.702,
#        26.245, 26.788, 27.331, 27.874, 28.417, 28.96 , 29.503, 30.046,
#        30.589, 31.132, 31.675, 32.218, 32.761, 33.304, 33.847, 34.39 ,
#        34.933, 35.476, 36.019, 36.562, 37.105, 37.648, 38.191, 38.734,
#        39.277, 39.82 , 40.363, 40.906, 41.449, 41.992, 42.535, 43.078,
#        43.621, 44.164, 44.707, 45.25 , 45.793, 46.336, 46.879, 47.422,
#        47.965, 48.508, 49.051, 49.594, 50.137, 50.68 , 51.223, 51.766,
#        52.309, 52.852, 53.395, 53.938, 54.481, 55.024, 55.567, 56.11 ,
#        56.653, 57.196, 57.739, 58.282, 58.825, 59.368, 59.911, 60.454,
#        60.997, 61.54 , 62.083, 62.626, 63.169, 63.712, 64.255, 64.798,
#        65.341, 65.884, 66.427, 66.97 , 67.513, 68.056, 68.599, 69.142,
#        69.685, 70.228, 70.771, 71.314, 71.857])

# %%
stresses_mpa = sig_yy*1000
xx_m = xx*10**(-9)
#         2840.25628424,  2801.95894142,  2765.17013842,  2729.79337061,
#         2695.74056103,  2662.93113707,  2631.29122798,  2600.75296472,
#         2571.25386729,  2542.7363067 ,  2515.14703127,  2488.43674818,
#         2462.55975297,  2437.47360049,  2413.13881204,  2389.51861404,
#         2366.57870425,  2344.28704228,  2322.61366137,  2301.53049897,
#         2281.01124395,  2261.03119849,  2241.56715314,  2222.59727338,
#         2204.10099669,  2186.05893882,  2168.45280837,  2151.26532883,
#         2134.48016733,  2118.08186938,  2102.05579902,  2086.38808396,
#         2071.06556509,  2056.07574999,  2041.40677015,  2027.04734147,
#         2012.98672776,  1999.21470703,  1985.7215402 ,  1972.49794223,
#         1959.5350552 ,  1946.82442341,  1934.35797019,  1922.12797633,
#         1910.12705999,  1898.34815798,  1886.78450831,  1875.42963382,
#         1864.27732701,  1853.32163571,  1842.55684977,  1831.97748854,
#         1821.57828918,  1811.35419558,  1801.30034811,  1791.41207388,
#         1781.68487761,  1772.11443303,  1762.69657486,  1753.42729112,
#         1744.30271596,  1735.31912293,  1726.47291855,  1717.76063628,
#         1709.17893079,  1700.72457261,  1692.39444299,  1684.18552906,
#         1676.09491928,  1668.11979909,  1660.25744676,  1652.50522956,
#         1644.86059999,  1637.32109231,  1629.88431915,  1622.5479684 ,
#         1615.3098001 ,  1608.16764368,  1601.1193951 ,  1594.16301436,
#         1587.29652294,  1580.51800148,  1573.8255875 ,  1567.21747327,
#         1560.69190375,  1554.24717462,  1547.88163044,  1541.59366282,
#         1535.38170875,  1529.24424897,  1523.17980638,  1517.18694456,
#         1511.26426635,  1505.41041246,  1499.62406018,  1493.90392213,
#         1488.24874503])

# %%
#remove the entry of the first atom
YY = YY[1:]
stresses_mpa = stresses_mpa[1:]

# %%
fig,ax = plt.subplots(figsize=(15,9),facecolor = 'white')
#plt.subplot(1,2,1)
plotss = plt.plot(YY,stresses_mpa,'--ko', linewidth=1, label = "normalized data for edge crack")
plt.xlabel('$x/W$')
plt.ylabel('$\sigma_{yy}/\sigma_{yy(boundary)}$')
#plt.xlim([0.66,0.75])
#plt.ylim([0, 13])
plt.rc('axes', titlesize=18) 
plt.rc('xtick', labelsize=18) 
plt.rc('ytick', labelsize=18) 
plt.rc('axes', labelsize=18)

#ax.legend()
plt.legend(loc=1, prop={'size': 18})
plt.legend(loc=1, prop={'size': 18})
plt.title('')
#grids
plt.minorticks_on()
#plt.grid (which='minor', color='g', ls='-.', lw=0.5)
#plt.grid(which='major',color='g', ls='--', lw=0.5)
#################for zooming particular range


plt.show()
#plt.savefig('edge_s_local_normalized.pdf',dpi = 1200)

# %%
kk = []

for i in range(6,25):
    print(i+1)
    ss_cut =stresses_mpa[4:i]
    y_cut = YY[4:i]

    m_x = np.mean(y_cut)
    m_y = np.mean(ss_cut)
    kic = m_y/m_x
    print(kic)

    b_0 = 0     
    b_1 = kic

    stress_fit = b_1 * y_cut + b_0 
    error = ss_cut - stress_fit
    n_1 = np.size(y_cut)
    ss_mean = np.mean(ss_cut)
    se = np.sum(error**2)
    print('squared error is', se)
    mse = se/n_1 
    print('mean squared error is', mse)
    SSt = np.sum((ss_cut - ss_mean)**2)
    R2 = 1- (se/SSt)
    print('R square is', R2)
# Out:
# 7
# 1.2844162817485458
# squared error is 0.0617698293350543
# mean squared error is 0.03088491466752715
# R square is 0.9999997991863924
# 8
# 1.2861549205820735
# squared error is 916.6330016779116
# mean squared error is 305.5443338926372
# R square is 0.9990247320593731
# 9
# 1.2883189732902955
# squared error is 3638.3717810419757
# mean squared error is 909.5929452604939
# R square is 0.9980656332975585
# 10
# 1.291936996194343
# squared error is 15564.045002616209
# mean squared error is 3112.8090005232416
# R square is 0.9948338267815616
# 11
# 1.2950507797559492
# squared error is 28567.93376244895
# mean squared error is 4761.322293741491
# R square is 0.9935067010267407
# 12
# 1.2975676765793185
# squared error is 40324.495646386364
# mean squared error is 5760.642235198052
# R square is 0.9933130658031932
# 13
# 1.301677780311222
# squared error is 78478.4386605102
# mean squared error is 9809.804832563776
# R square is 0.989723493490963
# 14
# 1.3052758229896129
# squared error is 115672.30878213848
# mean squared error is 12852.478753570942
# R square is 0.9877175647543615
# 15
# 1.3097292498061266
# squared error is 183063.0671808193
# mean squared error is 18306.306718081927
# R square is 0.9836063549550131
# 16
# 1.3144190471587038
# squared error is 271651.48767269216
# mean squared error is 24695.58978842656
# R square is 0.9790083256241521
# 17
# 1.3185922845947475
# squared error is 355322.64716263354
# mean squared error is 29610.220596886127
# R square is 0.9760677295038217
# 18
# 1.322815823274435
# squared error is 453858.6494593937
# mean squared error is 34912.203804568744
# R square is 0.9729521562846928
# 19
# 1.3270558316608159
# squared error is 566828.7129785434
# mean squared error is 40487.7652127531
# R square is 0.9697433765565385
# 20
# 1.3319600739408344
# squared error is 732849.4400379048
# mean squared error is 48856.62933586032
# R square is 0.9643677275463832
# 21
# 1.3369793651849529
# squared error is 926792.1208387867
# mean squared error is 57924.50755242417
# R square is 0.9585856859374648
# 22
# 1.3418585685415736
# squared error is 1131498.0184029483
# mean squared error is 66558.70696487931
# R square is 0.9532775584152857
# 23
# 1.3459953416685309
# squared error is 1299495.1856502139
# mean squared error is 72194.17698056744
# R square is 0.9504484366817894
# 24
# 1.3516641261103037
# squared error is 1622703.5488368385
# mean squared error is 85405.44993878098
# R square is 0.9417477998371581
# 25
# 1.3572089761928228
# squared error is 1962095.140336331
# mean squared error is 98104.75701681655
# R square is 0.9334850944937755

# %%
ss_cut =stresses_mpa[4:5]
y_cut = YY[4:5]

m_x = np.mean(y_cut)
m_y = np.mean(ss_cut)
kic = m_y/m_x
print(kic)

b_0 = 0     
b_1 = kic

stress_fit = b_1 * y_cut + b_0 
error = ss_cut - stress_fit
n_1 = np.size(y_cut)
ss_mean = np.mean(ss_cut)
se = np.sum(error**2)
print('squared error is', se)
mse = se/n_1 
print('mean squared error is', mse)
SSt = np.sum((ss_cut - ss_mean)**2)
R2 = 1- (se/SSt)
print('R square is', R2)
# Out:
# 1.2844399879742974
# squared error is 0.0
# mean squared error is 0.0
# R square is nan
# C:\Users\AYANBA~1\AppData\Local\Temp/ipykernel_13980/3168904595.py:21: RuntimeWarning: invalid value encountered in double_scalars
#   R2 = 1- (se/SSt)

# %%
fig,ax = plt.subplots(figsize=(15,9),facecolor = 'white')
#plt.subplot(1,2,1)
plotss = plt.plot(y_cut,ss_cut,'ko', linewidth=1, label = "data points")
plotss = plt.plot(y_cut,stress_fit,'-k', linewidth=1, label = "linear fit")
plt.xlabel('$x/W$')
plt.ylabel('$\sigma_{yy}/\sigma_{yy(boundary)}$')
#plt.xlim([0.66,0.75])
#plt.ylim([0, 13])
plt.rc('axes', titlesize=18) 
plt.rc('xtick', labelsize=18) 
plt.rc('ytick', labelsize=18) 
plt.rc('axes', labelsize=18)

#ax.legend()
plt.legend(loc=2, prop={'size': 18})
plt.legend(loc=2, prop={'size': 18})
plt.title('')
#grids
plt.minorticks_on()
#plt.grid (which='minor', color='g', ls='-.', lw=0.5)
#plt.grid(which='major',color='g', ls='--', lw=0.5)
#################for zooming particular range


plt.show()

# %%
array = [pos_x,sig_yy,normalized_x,normalized_stress]

df = pd.DataFrame(array).T
df.to_excel(excel_writer = "nd_0.575.xlsx")
