# %%
import matplotlib as mpl
mpl.rcParams['font.family']='serif'
mpl.rcParams['mathtext.fontset']='cm'
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
dt = pd.read_excel (r'stress_data_90.xlsx')
mat = dt.to_numpy()
new_mat=np.transpose(mat)

# %%
pos_x = new_mat[1]
pos_x = pos_x/10
pos_x
# Out:
# array([144.981, 145.524, 146.067, 146.61 , 147.153, 147.696, 148.239,
#        148.782, 149.325, 149.868, 150.411, 150.954, 151.497, 152.04 ,
#        152.583, 153.126, 153.669, 154.212, 154.755, 155.298, 155.841,
#        156.384, 156.927, 157.47 , 158.013, 158.556, 159.099, 159.642,
#        160.185, 160.728, 161.271, 161.814, 162.357, 162.9  , 163.443,
#        163.986, 164.529, 165.072, 165.615, 166.158, 166.701, 167.244,
#        167.787, 168.33 , 168.873, 169.416, 169.959, 170.502, 171.045,
#        171.588, 172.131, 172.674, 173.217, 173.76 , 174.303, 174.846,
#        175.389, 175.932, 176.475, 177.018, 177.561, 178.104, 178.647,
#        179.19 , 179.733, 180.276, 180.819, 181.362, 181.905, 182.448,
#        182.991, 183.534, 184.077, 184.62 , 185.163, 185.706, 186.249,
#        186.792, 187.335, 187.878, 188.421, 188.964, 189.507, 190.05 ,
#        190.593, 191.136, 191.679, 192.222, 192.765, 193.308, 193.851,
#        194.394, 194.937, 195.48 , 196.023, 196.566, 197.109, 197.652,
#        198.195, 198.738, 199.281, 199.824, 200.367, 200.91 , 201.453,
#        201.996, 202.539, 203.082, 203.625, 204.168, 204.711, 205.254,
#        205.797, 206.34 , 206.883, 207.426, 207.969, 208.512, 209.055,
#        209.598, 210.141, 210.684, 211.227, 211.77 , 212.313, 212.856,
#        213.399, 213.942, 214.485, 215.028, 215.571, 216.114, 216.657])

# %%
sig_yy =new_mat[12]
sig_yy
# Out:
# array([12.76966293,  9.08897859,  6.77328223,  5.70805105,  5.00502741,
#         4.51932491,  4.19404533,  3.95530977,  3.74334439,  3.52629548,
#         3.37388957,  3.30964533,  3.15105604,  3.05753786,  2.95026439,
#         2.91463416,  2.85701936,  2.81514488,  2.76722582,  2.75250885,
#         2.74634625,  2.75645099,  2.75111016,  2.7465407 ,  2.74326434,
#         2.73838708,  2.71798665,  2.73058048,  2.72925277,  2.72455774,
#         2.72319651,  2.71738378,  2.70013037,  2.71281914,  2.71179568,
#         2.70793291,  2.70483232,  2.7044193 ,  2.68628764,  2.69883892,
#         2.69528998,  2.69456316,  2.68934322,  2.68908569,  2.68793254,
#         2.68313198,  2.67857364,  2.66856193,  2.63784258,  2.63286069,
#         2.63644654,  2.63609461,  2.61428949,  2.60657675,  2.60003845,
#         2.58789229,  2.57368569,  2.5677282 ,  2.56113335,  2.54825211,
#         2.52769537,  2.5300388 ,  2.51500118,  2.49101562,  2.48038992,
#         2.45471251,  2.4432833 ,  2.43914063,  2.42091897,  2.41868134,
#         2.40656688,  2.39723216,  2.38970564,  2.39168564,  2.3856561 ,
#         2.38505258,  2.38291847,  2.38313659,  2.38123216,  2.37757375,
#         2.37529508,  2.37510432,  2.37224532,  2.3733134 ,  2.37020526,
#         2.36673259,  2.3676384 ,  2.36494479,  2.36463822,  2.36149045,
#         2.36070951,  2.35669389,  2.35792096,  2.35726363,  2.35612697,
#         2.35403948,  2.35210588,  2.35155713,  2.34998221,  2.34770989,
#         2.34732058,  2.34813152,  2.34784196,  2.34413017,  2.34130426,
#         2.33951746,  2.33295125,  2.33173715,  2.32863196,  2.32573743,
#         2.31996737,  2.31977952,  2.30924031,  2.30374286,  2.30045951,
#         2.29666875,  2.29032137,  2.28880539,  2.27446958,  2.26832137,
#         2.26543898,  2.25907272,  2.25556626,  2.24882874,  2.23667846,
#         2.2219499 ,  2.22078381,  2.21931042,  2.21315646,  2.19566949,
#         2.18606625,  2.17186445,  2.16996598])

# %%
fig,ax = plt.subplots(figsize=(15,9),facecolor = 'white')
#plt.subplot(1,2,1)
plotss = plt.plot(pos_x,sig_yy,'--ko', linewidth=1, label = "$\sigma_{yy}$ curve obtained from MD")
plt.xlabel('X co-ordinate of atom position (nm)')
plt.ylabel('$\sigma_{yy}$ (GPa)')
#plt.xlim([0.66,0.75])
#plt.ylim([0, 13])
plt.rc('axes', titlesize=18) 
plt.rc('xtick', labelsize=18) 
plt.rc('ytick', labelsize=18) 
plt.rc('axes', labelsize=18)

#ax.legend()
plt.legend(loc=1, prop={'size': 18})
plt.legend(loc=1, prop={'size': 18})
plt.title('')
#grids
plt.minorticks_on()
#plt.grid (which='minor', color='g', ls='-.', lw=0.5)
#plt.grid(which='major',color='g', ls='--', lw=0.5)
#################for zooming particular range


#plt.show()
plt.savefig('mid_50_s_local.pdf',dpi = 1200)

# %%
boundary_stress = 1.044594202

total_width = 217.2

# %%
normalized_stress = sig_yy/boundary_stress
normalized_x = pos_x/total_width

# %%
fig,ax = plt.subplots(figsize=(15,9),facecolor = 'white')
#plt.subplot(1,2,1)
plotss = plt.plot(normalized_x,normalized_stress,'--ko', linewidth=1, label = "normalized data for edge crack")
plt.xlabel('$x/W$')
plt.ylabel('$\sigma_{yy}/\sigma_{yy(boundary)}$')
#plt.xlim([0.66,0.75])
#plt.ylim([0, 13])
plt.rc('axes', titlesize=18) 
plt.rc('xtick', labelsize=18) 
plt.rc('ytick', labelsize=18) 
plt.rc('axes', labelsize=18)

#ax.legend()
plt.legend(loc=1, prop={'size': 18})
plt.legend(loc=1, prop={'size': 18})
plt.title('')
#grids
plt.minorticks_on()
#plt.grid (which='minor', color='g', ls='-.', lw=0.5)
#plt.grid(which='major',color='g', ls='--', lw=0.5)
#################for zooming particular range


#plt.show()
plt.savefig('mid_50_s_local_normalized.pdf',dpi = 1200)

# %%
xx = pos_x-(2*total_width/3)
xx
# Out:
# array([ 0.181,  0.724,  1.267,  1.81 ,  2.353,  2.896,  3.439,  3.982,
#         4.525,  5.068,  5.611,  6.154,  6.697,  7.24 ,  7.783,  8.326,
#         8.869,  9.412,  9.955, 10.498, 11.041, 11.584, 12.127, 12.67 ,
#        13.213, 13.756, 14.299, 14.842, 15.385, 15.928, 16.471, 17.014,
#        17.557, 18.1  , 18.643, 19.186, 19.729, 20.272, 20.815, 21.358,
#        21.901, 22.444, 22.987, 23.53 , 24.073, 24.616, 25.159, 25.702,
#        26.245, 26.788, 27.331, 27.874, 28.417, 28.96 , 29.503, 30.046,
#        30.589, 31.132, 31.675, 32.218, 32.761, 33.304, 33.847, 34.39 ,
#        34.933, 35.476, 36.019, 36.562, 37.105, 37.648, 38.191, 38.734,
#        39.277, 39.82 , 40.363, 40.906, 41.449, 41.992, 42.535, 43.078,
#        43.621, 44.164, 44.707, 45.25 , 45.793, 46.336, 46.879, 47.422,
#        47.965, 48.508, 49.051, 49.594, 50.137, 50.68 , 51.223, 51.766,
#        52.309, 52.852, 53.395, 53.938, 54.481, 55.024, 55.567, 56.11 ,
#        56.653, 57.196, 57.739, 58.282, 58.825, 59.368, 59.911, 60.454,
#        60.997, 61.54 , 62.083, 62.626, 63.169, 63.712, 64.255, 64.798,
#        65.341, 65.884, 66.427, 66.97 , 67.513, 68.056, 68.599, 69.142,
#        69.685, 70.228, 70.771, 71.314, 71.857])

# %%
stresses_mpa = sig_yy*1000
xx_m = xx*10**(-9)
stresses_mpa
# Out:
# array([12769.66292934,  9088.97859083,  6773.28222926,  5708.05104505,
#         5005.02741285,  4519.32491392,  4194.04533486,  3955.30977391,
#         3743.34438892,  3526.29548165,  3373.88957173,  3309.64533259,
#         3151.0560362 ,  3057.53785557,  2950.26439339,  2914.63415501,
#         2857.01935502,  2815.14488209,  2767.22581625,  2752.50884767,
#         2746.34625418,  2756.45099272,  2751.11016234,  2746.54069505,
#         2743.26434427,  2738.38708202,  2717.98664951,  2730.58047873,
#         2729.25276596,  2724.55774101,  2723.19651128,  2717.38377592,
#         2700.13037249,  2712.81913939,  2711.795678  ,  2707.93290579,
#         2704.83232285,  2704.41929725,  2686.28764477,  2698.83892301,
#         2695.28998342,  2694.56316402,  2689.3432197 ,  2689.08569087,
#         2687.93254277,  2683.13197768,  2678.57363992,  2668.5619326 ,
#         2637.84258082,  2632.86068834,  2636.44654448,  2636.09460794,
#         2614.28949239,  2606.57675157,  2600.03844885,  2587.89229261,
#         2573.68569339,  2567.72819504,  2561.13334648,  2548.25210915,
#         2527.69536862,  2530.03879577,  2515.0011765 ,  2491.01561503,
#         2480.38992491,  2454.71250752,  2443.28330365,  2439.14063382,
#         2420.9189748 ,  2418.68134375,  2406.56688383,  2397.23216289,
#         2389.70564455,  2391.68564311,  2385.65610106,  2385.05258046,
#         2382.91846916,  2383.13659247,  2381.23216299,  2377.5737474 ,
#         2375.29508377,  2375.10431903,  2372.24531601,  2373.31340234,
#         2370.20526458,  2366.73258614,  2367.63840439,  2364.94479241,
#         2364.63822422,  2361.49045236,  2360.70950783,  2356.69388587,
#         2357.92096287,  2357.26363003,  2356.12697054,  2354.03948481,
#         2352.10587802,  2351.55713021,  2349.9822082 ,  2347.70988902,
#         2347.32058109,  2348.13152419,  2347.84196276,  2344.13016789,
#         2341.30425806,  2339.51745926,  2332.95124791,  2331.73714894,
#         2328.63195505,  2325.73743227,  2319.96737138,  2319.77952265,
#         2309.24030521,  2303.74286014,  2300.45950959,  2296.66874834,
#         2290.32137149,  2288.80538773,  2274.46957816,  2268.32137474,
#         2265.43898466,  2259.07272313,  2255.56625741,  2248.82873781,
#         2236.67846014,  2221.94989867,  2220.78381453,  2219.31041875,
#         2213.15646385,  2195.66949422,  2186.06625052,  2171.86444963,
#         2169.96598325])

# %%
Y_inv = np.sqrt(2*np.pi*xx_m)
YY = 1/Y_inv
YY
# Out:
# array([29653.14617129, 14826.57308564, 11207.8357657 ,  9377.14816912,
#         8224.30299995,  7413.28654282,  6802.89829046,  6322.07200592,
#         5930.62923426,  5603.91788285,  5325.86227414,  5085.4726134 ,
#         4874.94720098,  4688.57408456,  4522.06239699,  4372.11787764,
#         4236.16373876,  4112.15149998,  3998.42941406,  3893.64884682,
#         3796.69631597,  3706.64327141,  3622.70839116,  3544.22886607,
#         3470.63824586,  3401.44914523,  3336.23959817,  3274.64218462,
#         3216.33528735,  3161.03600296,  3108.49434925,  3058.48849795,
#         3010.82082492,  2965.31461713,  2921.81131123,  2880.16816506,
#         2840.25628424,  2801.95894142,  2765.17013842,  2729.79337061,
#         2695.74056103,  2662.93113707,  2631.29122798,  2600.75296472,
#         2571.25386729,  2542.7363067 ,  2515.14703127,  2488.43674818,
#         2462.55975297,  2437.47360049,  2413.13881204,  2389.51861404,
#         2366.57870425,  2344.28704228,  2322.61366137,  2301.53049897,
#         2281.01124395,  2261.03119849,  2241.56715314,  2222.59727338,
#         2204.10099669,  2186.05893882,  2168.45280837,  2151.26532883,
#         2134.48016733,  2118.08186938,  2102.05579902,  2086.38808396,
#         2071.06556509,  2056.07574999,  2041.40677015,  2027.04734147,
#         2012.98672776,  1999.21470703,  1985.7215402 ,  1972.49794223,
#         1959.5350552 ,  1946.82442341,  1934.35797019,  1922.12797633,
#         1910.12705999,  1898.34815798,  1886.78450831,  1875.42963382,
#         1864.27732701,  1853.32163571,  1842.55684977,  1831.97748854,
#         1821.57828918,  1811.35419558,  1801.30034811,  1791.41207388,
#         1781.68487761,  1772.11443303,  1762.69657486,  1753.42729112,
#         1744.30271596,  1735.31912293,  1726.47291855,  1717.76063628,
#         1709.17893079,  1700.72457261,  1692.39444299,  1684.18552906,
#         1676.09491928,  1668.11979909,  1660.25744676,  1652.50522956,
#         1644.86059999,  1637.32109231,  1629.88431915,  1622.5479684 ,
#         1615.3098001 ,  1608.16764368,  1601.1193951 ,  1594.16301436,
#         1587.29652294,  1580.51800148,  1573.8255875 ,  1567.21747327,
#         1560.69190375,  1554.24717462,  1547.88163044,  1541.59366282,
#         1535.38170875,  1529.24424897,  1523.17980638,  1517.18694456,
#         1511.26426635,  1505.41041246,  1499.62406018,  1493.90392213,
#         1488.24874503])

# %%
#remove the entry of the first atom
YY = YY[1:]
stresses_mpa = stresses_mpa[1:]

# %%
fig,ax = plt.subplots(figsize=(15,9),facecolor = 'white')
#plt.subplot(1,2,1)
plotss = plt.plot(YY,stresses_mpa,'--ko', linewidth=1, label = "normalized data for edge crack")
plt.xlabel('$x/W$')
plt.ylabel('$\sigma_{yy}/\sigma_{yy(boundary)}$')
#plt.xlim([0.66,0.75])
#plt.ylim([0, 13])
plt.rc('axes', titlesize=18) 
plt.rc('xtick', labelsize=18) 
plt.rc('ytick', labelsize=18) 
plt.rc('axes', labelsize=18)

#ax.legend()
plt.legend(loc=1, prop={'size': 18})
plt.legend(loc=1, prop={'size': 18})
plt.title('')
#grids
plt.minorticks_on()
#plt.grid (which='minor', color='g', ls='-.', lw=0.5)
#plt.grid(which='major',color='g', ls='--', lw=0.5)
#################for zooming particular range


plt.show()
#plt.savefig('edge_s_local_normalized.pdf',dpi = 1200)

# %%
ss_cut =stresses_mpa[4:5]
y_cut = YY[4:5]

# %%
m_x = np.mean(y_cut)
m_y = np.mean(ss_cut)
kic = m_y/m_x
kic
# Out:
# 0.6096250141981109

# %%
b_0 = 0     
b_1 = 0.6110748054245662

# %%
stress_fit = b_1 * y_cut + b_0 
error = ss_cut - stress_fit
n_1 = np.size(y_cut)
ss_mean = np.mean(ss_cut)
se = np.sum(error**2)
print('squared error is', se)
mse = se/n_1 
print('mean squared error is', mse)
SSt = np.sum((ss_cut - ss_mean)**2)
R2 = 1- (se/SSt)
print('R square is', R2)
# Out:
# squared error is 16575.958670440938
# mean squared error is 2762.659778406823
# R square is 0.997047322786079

# %%
for i in range(6,23):
    print(i+1)
    ss_cut =stresses_mpa[4:i]
    y_cut = YY[4:i]

    m_x = np.mean(y_cut)
    m_y = np.mean(ss_cut)
    kic = m_y/m_x
    print(kic)

    b_0 = 0     
    b_1 = kic

    stress_fit = b_1 * y_cut + b_0 
    error = ss_cut - stress_fit
    n_1 = np.size(y_cut)
    ss_mean = np.mean(ss_cut)
    se = np.sum(error**2)
    print('squared error is', se)
    mse = se/n_1 
    print('mean squared error is', mse)
    SSt = np.sum((ss_cut - ss_mean)**2)
    R2 = 1- (se/SSt)
    print('R square is', R2)
# Out:
# 7
# 0.6129190321431981
# squared error is 1192.6238534575482
# mean squared error is 596.3119267287741
# R square is 0.977456575529898
# 8
# 0.6168332649594663
# squared error is 5956.789573787235
# mean squared error is 1985.596524595745
# R square is 0.962840864988102
# 9
# 0.6200496827133121
# squared error is 12163.411473242433
# mean squared error is 3040.8528683106083
# R square is 0.9634491183395298
# 10
# 0.6216581475207611
# squared error is 14824.026870797843
# mean squared error is 2964.8053741595686
# R square is 0.975246106009357
# 11
# 0.6233433385392668
# squared error is 18897.838626763034
# mean squared error is 3149.6397711271725
# R square is 0.9792965941539131
# 12
# 0.6266304442569137
# squared error is 38068.70032102642
# mean squared error is 5438.385760146632
# R square is 0.9681937783441711
# 13
# 0.6286631208553644
# squared error is 48154.52406582153
# mean squared error is 6019.315508227692
# R square is 0.9693075313940355
# 14
# 0.6307766498582307
# squared error is 61529.06256899561
# mean squared error is 6836.562507666178
# R square is 0.968622564487842
# 15
# 0.6325064271983925
# squared error is 72722.95735320903
# mean squared error is 7272.295735320903
# R square is 0.9696844748235189
# 16
# 0.6349553440007579
# squared error is 97565.01957009712
# mean squared error is 8869.547233645193
# R square is 0.965142948377883
# 17
# 0.6375213101304528
# squared error is 129179.21800548956
# mean squared error is 10764.934833790796
# R square is 0.9596213879478392
# 18
# 0.6403147902226369
# squared error is 171765.04330175562
# mean squared error is 13212.695638596586
# R square is 0.952104786331167
# 19
# 0.6431388633658848
# squared error is 221295.0256898824
# mean squared error is 15806.787549277315
# R square is 0.9443054142003131
# 20
# 0.6463565980881858
# squared error is 292273.6027716702
# mean squared error is 19484.90685144468
# R square is 0.9324305021674155
# 21
# 0.6499665067227541
# squared error is 390523.7464169455
# mean squared error is 24407.734151059092
# R square is 0.9158412907079021
# 22
# 0.6540670518288351
# squared error is 528844.3189219398
# mean squared error is 31108.4893483494
# R square is 0.8922452535388655
# 23
# 0.6583884581246366
# squared error is 697527.2923686322
# mean squared error is 38751.516242701786
# R square is 0.8645773324893284

# %%
fig,ax = plt.subplots(figsize=(15,9),facecolor = 'white')
#plt.subplot(1,2,1)
plotss = plt.plot(y_cut,ss_cut,'ko', linewidth=1, label = "data points")
plotss = plt.plot(y_cut,stress_fit,'-k', linewidth=1, label = "linear fit")
plt.xlabel('$x/W$')
plt.ylabel('$\sigma_{yy}/\sigma_{yy(boundary)}$')
#plt.xlim([0.66,0.75])
#plt.ylim([0, 13])
plt.rc('axes', titlesize=18) 
plt.rc('xtick', labelsize=18) 
plt.rc('ytick', labelsize=18) 
plt.rc('axes', labelsize=18)

#ax.legend()
plt.legend(loc=2, prop={'size': 18})
plt.legend(loc=2, prop={'size': 18})
plt.title('')
#grids
plt.minorticks_on()
#plt.grid (which='minor', color='g', ls='-.', lw=0.5)
#plt.grid(which='major',color='g', ls='--', lw=0.5)
#################for zooming particular range


plt.show()

# %%
array = [pos_x,sig_yy,normalized_x,normalized_stress]

df = pd.DataFrame(array).T
df.to_excel(excel_writer = "nd_0.90.xlsx")
