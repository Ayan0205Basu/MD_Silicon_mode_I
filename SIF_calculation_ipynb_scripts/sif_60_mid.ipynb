# %%
import matplotlib as mpl
mpl.rcParams['font.family']='serif'
mpl.rcParams['mathtext.fontset']='cm'
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
dt = pd.read_excel (r'stress_data_60.xlsx')
mat = dt.to_numpy()
new_mat=np.transpose(mat)

# %%
pos_x = new_mat[1]
pos_x = pos_x/10
pos_x
# Out:
# array([144.981, 145.524, 146.067, 146.61 , 147.153, 147.696, 148.239,
#        148.782, 149.325, 149.868, 150.411, 150.954, 151.497, 152.04 ,
#        152.583, 153.126, 153.669, 154.212, 154.755, 155.298, 155.841,
#        156.384, 156.927, 157.47 , 158.013, 158.556, 159.099, 159.642,
#        160.185, 160.728, 161.271, 161.814, 162.357, 162.9  , 163.443,
#        163.986, 164.529, 165.072, 165.615, 166.158, 166.701, 167.244,
#        167.787, 168.33 , 168.873, 169.416, 169.959, 170.502, 171.045,
#        171.588, 172.131, 172.674, 173.217, 173.76 , 174.303, 174.846,
#        175.389, 175.932, 176.475, 177.018, 177.561, 178.104, 178.647,
#        179.19 , 179.733, 180.276, 180.819, 181.362, 181.905, 182.448,
#        182.991, 183.534, 184.077, 184.62 , 185.163, 185.706, 186.249,
#        186.792, 187.335, 187.878, 188.421, 188.964, 189.507, 190.05 ,
#        190.593, 191.136, 191.679, 192.222, 192.765, 193.308, 193.851,
#        194.394, 194.937, 195.48 , 196.023, 196.566, 197.109, 197.652,
#        198.195, 198.738, 199.281, 199.824, 200.367, 200.91 , 201.453,
#        201.996, 202.539, 203.082, 203.625, 204.168, 204.711, 205.254,
#        205.797, 206.34 , 206.883, 207.426, 207.969, 208.512, 209.055,
#        209.598, 210.141, 210.684, 211.227, 211.77 , 212.313, 212.856,
#        213.399, 213.942, 214.485, 215.028, 215.571, 216.114, 216.657])

# %%
sig_yy =new_mat[12]
sig_yy
# Out:
# array([32.09985817, 21.64465603, 15.01031034, 12.20039625, 10.58715788,
#         9.59908699,  8.79467079,  8.18661468,  7.79423466,  7.41183061,
#         7.09815484,  6.8825814 ,  6.658039  ,  6.46103083,  6.20589284,
#         6.07611396,  5.94724709,  5.88798657,  5.70958668,  5.59540397,
#         5.47714919,  5.32817254,  5.29943948,  5.23384168,  5.18075772,
#         5.14235182,  5.00818524,  5.00570964,  4.97068098,  4.90882635,
#         4.82745803,  4.80257378,  4.71996227,  4.71912856,  4.61599799,
#         4.66145243,  4.59689101,  4.60199154,  4.52632487,  4.57653239,
#         4.49589883,  4.44726224,  4.44762395,  4.42305996,  4.41948622,
#         4.34400657,  4.38129684,  4.38695791,  4.31160772,  4.25947592,
#         4.32618281,  4.28694863,  4.23541396,  4.21986244,  4.1744187 ,
#         4.21975595,  4.20185828,  4.17471332,  4.15337652,  4.10375872,
#         4.10840963,  4.09793053,  4.09407732,  4.01555964,  4.00997225,
#         4.0270338 ,  4.03648014,  4.08226669,  4.01422681,  3.99089996,
#         3.99267179,  3.98894077,  3.95718743,  3.91692705,  3.95918331,
#         3.94351926,  3.91787816,  3.92019714,  3.86798396,  3.84506366,
#         3.90018094,  3.86339959,  3.81118515,  3.82951194,  3.79824168,
#         3.78512772,  3.817845  ,  3.8087217 ,  3.76708151,  3.75961999,
#         3.76583533,  3.7496215 ,  3.7312864 ,  3.66719045,  3.72153203,
#         3.71293387,  3.69786899,  3.75115408,  3.6439435 ,  3.65572662,
#         3.64718989,  3.63584333,  3.67721975,  3.64659021,  3.60528557,
#         3.57837126,  3.59953062,  3.56020396,  3.59827782,  3.55276252,
#         3.57359378,  3.54575296,  3.53700843,  3.54335364,  3.53989059,
#         3.55152785,  3.50387205,  3.43784798,  3.4868281 ,  3.49566854,
#         3.49013323,  3.40324902,  3.38224301,  3.42950042,  3.3541325 ,
#         3.36924547,  3.37676163,  3.40014586,  3.35372553,  3.3613941 ,
#         3.37384222,  3.31723899,  3.34458302])

# %%
fig,ax = plt.subplots(figsize=(15,9),facecolor = 'white')
#plt.subplot(1,2,1)
plotss = plt.plot(pos_x,sig_yy,'--ko', linewidth=1, label = "$\sigma_{yy}$ curve obtained from MD")
plt.xlabel('X co-ordinate of atom position (nm)')
plt.ylabel('$\sigma_{yy}$ (GPa)')
#plt.xlim([0.66,0.75])
#plt.ylim([0, 13])
plt.rc('axes', titlesize=18) 
plt.rc('xtick', labelsize=18) 
plt.rc('ytick', labelsize=18) 
plt.rc('axes', labelsize=18)

#ax.legend()
plt.legend(loc=1, prop={'size': 18})
plt.legend(loc=1, prop={'size': 18})
plt.title('')
#grids
plt.minorticks_on()
#plt.grid (which='minor', color='g', ls='-.', lw=0.5)
#plt.grid(which='major',color='g', ls='--', lw=0.5)
#################for zooming particular range


#plt.show()
plt.savefig('mid_60_s_local.pdf',dpi = 1200)

# %%
boundary_stress = 3.300907387
total_width = 217.2

# %%
normalized_stress = sig_yy/boundary_stress
normalized_x = pos_x/total_width

# %%
fig,ax = plt.subplots(figsize=(15,9),facecolor = 'white')
#plt.subplot(1,2,1)
plotss = plt.plot(normalized_x,normalized_stress,'--ko', linewidth=1, label = "normalized data for edge crack")
plt.xlabel('$x/W$')
plt.ylabel('$\sigma_{yy}/\sigma_{yy(boundary)}$')
#plt.xlim([0.66,0.75])
#plt.ylim([0, 13])
plt.rc('axes', titlesize=18) 
plt.rc('xtick', labelsize=18) 
plt.rc('ytick', labelsize=18) 
plt.rc('axes', labelsize=18)

#ax.legend()
plt.legend(loc=1, prop={'size': 18})
plt.legend(loc=1, prop={'size': 18})
plt.title('')
#grids
plt.minorticks_on()
#plt.grid (which='minor', color='g', ls='-.', lw=0.5)
#plt.grid(which='major',color='g', ls='--', lw=0.5)
#################for zooming particular range


#plt.show()
plt.savefig('mid_60_s_local_normalized.pdf',dpi = 1200)

# %%
xx = pos_x-(2*total_width/3)
xx
# Out:
# array([ 0.181,  0.724,  1.267,  1.81 ,  2.353,  2.896,  3.439,  3.982,
#         4.525,  5.068,  5.611,  6.154,  6.697,  7.24 ,  7.783,  8.326,
#         8.869,  9.412,  9.955, 10.498, 11.041, 11.584, 12.127, 12.67 ,
#        13.213, 13.756, 14.299, 14.842, 15.385, 15.928, 16.471, 17.014,
#        17.557, 18.1  , 18.643, 19.186, 19.729, 20.272, 20.815, 21.358,
#        21.901, 22.444, 22.987, 23.53 , 24.073, 24.616, 25.159, 25.702,
#        26.245, 26.788, 27.331, 27.874, 28.417, 28.96 , 29.503, 30.046,
#        30.589, 31.132, 31.675, 32.218, 32.761, 33.304, 33.847, 34.39 ,
#        34.933, 35.476, 36.019, 36.562, 37.105, 37.648, 38.191, 38.734,
#        39.277, 39.82 , 40.363, 40.906, 41.449, 41.992, 42.535, 43.078,
#        43.621, 44.164, 44.707, 45.25 , 45.793, 46.336, 46.879, 47.422,
#        47.965, 48.508, 49.051, 49.594, 50.137, 50.68 , 51.223, 51.766,
#        52.309, 52.852, 53.395, 53.938, 54.481, 55.024, 55.567, 56.11 ,
#        56.653, 57.196, 57.739, 58.282, 58.825, 59.368, 59.911, 60.454,
#        60.997, 61.54 , 62.083, 62.626, 63.169, 63.712, 64.255, 64.798,
#        65.341, 65.884, 66.427, 66.97 , 67.513, 68.056, 68.599, 69.142,
#        69.685, 70.228, 70.771, 71.314, 71.857])

# %%
stresses_mpa = sig_yy*1000
xx_m = xx*10**(-9)
stresses_mpa
# Out:
# array([32099.85816819, 21644.65603248, 15010.31034082, 12200.39625219,
#        10587.15788225,  9599.08698813,  8794.67078574,  8186.6146806 ,
#         7794.23466335,  7411.83060919,  7098.15484037,  6882.58139922,
#         6658.03900428,  6461.03082897,  6205.89283824,  6076.11395761,
#         5947.24709269,  5887.98657386,  5709.58668497,  5595.40397291,
#         5477.14918662,  5328.17253993,  5299.43947908,  5233.841683  ,
#         5180.75772407,  5142.35181931,  5008.18523817,  5005.70963864,
#         4970.6809796 ,  4908.82635026,  4827.45802798,  4802.57377526,
#         4719.9622659 ,  4719.12855596,  4615.9979866 ,  4661.45242707,
#         4596.89101052,  4601.99154132,  4526.32486609,  4576.53239395,
#         4495.89883173,  4447.26224152,  4447.62394831,  4423.05995505,
#         4419.48621751,  4344.00656887,  4381.29683976,  4386.95791361,
#         4311.60771578,  4259.47591577,  4326.18280551,  4286.94863076,
#         4235.41395733,  4219.86243517,  4174.41869784,  4219.75595496,
#         4201.85827768,  4174.71331578,  4153.3765152 ,  4103.75872013,
#         4108.40962818,  4097.93053138,  4094.07732109,  4015.55963583,
#         4009.9722461 ,  4027.03380463,  4036.48013524,  4082.26669014,
#         4014.22681277,  3990.89995892,  3992.67178704,  3988.94077236,
#         3957.18743029,  3916.92704995,  3959.18330806,  3943.51926405,
#         3917.87816007,  3920.19714374,  3867.98396141,  3845.06366095,
#         3900.18093702,  3863.399593  ,  3811.18515472,  3829.51194182,
#         3798.24168293,  3785.1277151 ,  3817.84499778,  3808.72169652,
#         3767.08151378,  3759.61999147,  3765.83533175,  3749.62149931,
#         3731.28640037,  3667.19045298,  3721.53203056,  3712.93386788,
#         3697.86898742,  3751.15408218,  3643.94349593,  3655.7266189 ,
#         3647.18988671,  3635.8433349 ,  3677.21975476,  3646.59021182,
#         3605.28556818,  3578.37125846,  3599.53061907,  3560.20395576,
#         3598.27782078,  3552.76251974,  3573.5937784 ,  3545.75295695,
#         3537.00843205,  3543.35363642,  3539.89059358,  3551.52784671,
#         3503.87205056,  3437.84798018,  3486.82810355,  3495.66853986,
#         3490.13322932,  3403.24901956,  3382.24300728,  3429.50042252,
#         3354.13249992,  3369.24546702,  3376.76163006,  3400.14585782,
#         3353.72553052,  3361.39409611,  3373.84222283,  3317.23898803,
#         3344.58301528])

# %%
Y_inv = np.sqrt(2*np.pi*xx_m)
YY = 1/Y_inv
YY
# Out:
# array([29653.14617129, 14826.57308564, 11207.8357657 ,  9377.14816912,
#         8224.30299995,  7413.28654282,  6802.89829046,  6322.07200592,
#         5930.62923426,  5603.91788285,  5325.86227414,  5085.4726134 ,
#         4874.94720098,  4688.57408456,  4522.06239699,  4372.11787764,
#         4236.16373876,  4112.15149998,  3998.42941406,  3893.64884682,
#         3796.69631597,  3706.64327141,  3622.70839116,  3544.22886607,
#         3470.63824586,  3401.44914523,  3336.23959817,  3274.64218462,
#         3216.33528735,  3161.03600296,  3108.49434925,  3058.48849795,
#         3010.82082492,  2965.31461713,  2921.81131123,  2880.16816506,
#         2840.25628424,  2801.95894142,  2765.17013842,  2729.79337061,
#         2695.74056103,  2662.93113707,  2631.29122798,  2600.75296472,
#         2571.25386729,  2542.7363067 ,  2515.14703127,  2488.43674818,
#         2462.55975297,  2437.47360049,  2413.13881204,  2389.51861404,
#         2366.57870425,  2344.28704228,  2322.61366137,  2301.53049897,
#         2281.01124395,  2261.03119849,  2241.56715314,  2222.59727338,
#         2204.10099669,  2186.05893882,  2168.45280837,  2151.26532883,
#         2134.48016733,  2118.08186938,  2102.05579902,  2086.38808396,
#         2071.06556509,  2056.07574999,  2041.40677015,  2027.04734147,
#         2012.98672776,  1999.21470703,  1985.7215402 ,  1972.49794223,
#         1959.5350552 ,  1946.82442341,  1934.35797019,  1922.12797633,
#         1910.12705999,  1898.34815798,  1886.78450831,  1875.42963382,
#         1864.27732701,  1853.32163571,  1842.55684977,  1831.97748854,
#         1821.57828918,  1811.35419558,  1801.30034811,  1791.41207388,
#         1781.68487761,  1772.11443303,  1762.69657486,  1753.42729112,
#         1744.30271596,  1735.31912293,  1726.47291855,  1717.76063628,
#         1709.17893079,  1700.72457261,  1692.39444299,  1684.18552906,
#         1676.09491928,  1668.11979909,  1660.25744676,  1652.50522956,
#         1644.86059999,  1637.32109231,  1629.88431915,  1622.5479684 ,
#         1615.3098001 ,  1608.16764368,  1601.1193951 ,  1594.16301436,
#         1587.29652294,  1580.51800148,  1573.8255875 ,  1567.21747327,
#         1560.69190375,  1554.24717462,  1547.88163044,  1541.59366282,
#         1535.38170875,  1529.24424897,  1523.17980638,  1517.18694456,
#         1511.26426635,  1505.41041246,  1499.62406018,  1493.90392213,
#         1488.24874503])

# %%
#remove the entry of the first atom
YY = YY[1:]
stresses_mpa = stresses_mpa[1:]

# %%
fig,ax = plt.subplots(figsize=(15,9),facecolor = 'white')
#plt.subplot(1,2,1)
plotss = plt.plot(YY,stresses_mpa,'--ko', linewidth=1, label = "normalized data for edge crack")
plt.xlabel('$x/W$')
plt.ylabel('$\sigma_{yy}/\sigma_{yy(boundary)}$')
#plt.xlim([0.66,0.75])
#plt.ylim([0, 13])
plt.rc('axes', titlesize=18) 
plt.rc('xtick', labelsize=18) 
plt.rc('ytick', labelsize=18) 
plt.rc('axes', labelsize=18)

#ax.legend()
plt.legend(loc=1, prop={'size': 18})
plt.legend(loc=1, prop={'size': 18})
plt.title('')
#grids
plt.minorticks_on()
#plt.grid (which='minor', color='g', ls='-.', lw=0.5)
#plt.grid(which='major',color='g', ls='--', lw=0.5)
#################for zooming particular range


plt.show()
#plt.savefig('edge_s_local_normalized.pdf',dpi = 1200)

# %%
ss_cut =stresses_mpa[4:5]
y_cut = YY[4:5]

# %%
m_x = np.mean(y_cut)
m_y = np.mean(ss_cut)
kic = m_y/m_x
kic
# Out:
# 1.294849043360996

# %%
b_0 = 0     
b_1 = 1.3045884760671416

# %%
stress_fit = b_1 * y_cut + b_0 
error = ss_cut - stress_fit
n_1 = np.size(y_cut)
ss_mean = np.mean(ss_cut)
se = np.sum(error**2)
print('squared error is', se)
mse = se/n_1 
print('mean squared error is', mse)
SSt = np.sum((ss_cut - ss_mean)**2)
R2 = 1- (se/SSt)
print('R square is', R2)
# Out:
# squared error is 5299570.693660408
# mean squared error is 5299570.693660408
# R square is -inf
# C:\Users\AYANBA~1\AppData\Local\Temp/ipykernel_19264/2174593048.py:10: RuntimeWarning: divide by zero encountered in double_scalars
#   R2 = 1- (se/SSt)

# %%
for i in range(6,24):
    print(i+1)
    ss_cut =stresses_mpa[4:i]
    y_cut = YY[4:i]

    m_x = np.mean(y_cut)
    m_y = np.mean(ss_cut)
    kic = m_y/m_x
    print(kic)

    b_0 = 0     
    b_1 = kic

    stress_fit = b_1 * y_cut + b_0 
    error = ss_cut - stress_fit
    n_1 = np.size(y_cut)
    ss_mean = np.mean(ss_cut)
    se = np.sum(error**2)
    print('squared error is', se)
    mse = se/n_1 
    print('mean squared error is', mse)
    SSt = np.sum((ss_cut - ss_mean)**2)
    R2 = 1- (se/SSt)
    print('R square is', R2)
# Out:
# 7
# 1.2938603422495327
# squared error is 107.44386302817233
# mean squared error is 53.721931514086165
# R square is 0.9996679144403573
# 8
# 1.294188336555458
# squared error is 137.14204832996728
# mean squared error is 45.714016109989096
# R square is 0.9998633996028992
# 9
# 1.2986797790594098
# squared error is 11488.357064824137
# mean squared error is 2872.089266206034
# R square is 0.9938103376168068
# 10
# 1.3028620068249872
# squared error is 27550.20086077522
# mean squared error is 5510.040172155044
# R square is 0.9907344966919133
# 11
# 1.3071212825123188
# squared error is 51716.22734093628
# mean squared error is 8619.371223489381
# R square is 0.987957836061041
# 12
# 1.3126586882598887
# squared error is 105843.57527240619
# mean squared error is 15120.510753200884
# R square is 0.9813191732596745
# 13
# 1.318125373277138
# squared error is 174343.17142641914
# mean squared error is 21792.896428302392
# R square is 0.9756656976589562
# 14
# 1.3235223952167554
# squared error is 257881.94896958032
# mean squared error is 28653.549885508924
# R square is 0.9705803884226
# 15
# 1.327426285379131
# squared error is 313692.96647038887
# mean squared error is 31369.296647038886
# R square is 0.9705536423038769
# 16
# 1.3318969374343854
# squared error is 398002.9190775019
# mean squared error is 36182.083552500175
# R square is 0.9682108811996617
# 17
# 1.3365781728693633
# squared error is 504825.2428218827
# mean squared error is 42068.770235156895
# R square is 0.9649402819505383
# 18
# 1.342232289703531
# squared error is 678561.3967793818
# mean squared error is 52197.03052149091
# R square is 0.9579465245123437
# 19
# 1.3469092201840243
# squared error is 818794.7007138189
# mean squared error is 58485.33576527278
# R square is 0.9546958736383939
# 20
# 1.3514570600588163
# squared error is 968708.0188070829
# mean squared error is 64580.53458713886
# R square is 0.951686881376459
# 21
# 1.3557307290807155
# squared error is 1118186.0123234657
# mean squared error is 69886.6257702166
# R square is 0.9493921489267648
# 22
# 1.3593082257268172
# squared error is 1238996.4019515784
# mean squared error is 72882.14129126932
# R square is 0.9490296852497385
# 23
# 1.3635554169932593
# squared error is 1417492.1178215237
# mean squared error is 78749.56210119576
# R square is 0.9462144034417602
# 24
# 1.3679220827527636
# squared error is 1622176.6945484853
# mean squared error is 85377.72076570976
# R square is 0.94280508417732

# %%
fig,ax = plt.subplots(figsize=(15,9),facecolor = 'white')
#plt.subplot(1,2,1)
plotss = plt.plot(y_cut,ss_cut,'ko', linewidth=1, label = "data points")
plotss = plt.plot(y_cut,stress_fit,'-k', linewidth=1, label = "linear fit")
plt.xlabel('$x/W$')
plt.ylabel('$\sigma_{yy}/\sigma_{yy(boundary)}$')
#plt.xlim([0.66,0.75])
#plt.ylim([0, 13])
plt.rc('axes', titlesize=18) 
plt.rc('xtick', labelsize=18) 
plt.rc('ytick', labelsize=18) 
plt.rc('axes', labelsize=18)

#ax.legend()
plt.legend(loc=2, prop={'size': 18})
plt.legend(loc=2, prop={'size': 18})
plt.title('')
#grids
plt.minorticks_on()
#plt.grid (which='minor', color='g', ls='-.', lw=0.5)
#plt.grid(which='major',color='g', ls='--', lw=0.5)
#################for zooming particular range


plt.show()

# %%
array = [pos_x,sig_yy,normalized_x,normalized_stress]

df = pd.DataFrame(array).T
df.to_excel(excel_writer = "nd_0.60.xlsx")
