# %%
import matplotlib as mpl
mpl.rcParams['font.family']='serif'
mpl.rcParams['mathtext.fontset']='cm'
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from matplotlib.pyplot import legend,gca
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes
from mpl_toolkits.axes_grid1.inset_locator import mark_inset

# %%
dt = pd.read_excel (r'stress_data_85.xlsx')
mat = dt.to_numpy()
new_mat=np.transpose(mat)

# %%
pos_x = new_mat[1]
pos_x = pos_x/10
pos_x
# Out:
# array([144.981, 145.524, 146.067, 146.61 , 147.153, 147.696, 148.239,
#        148.782, 149.325, 149.868, 150.411, 150.954, 151.497, 152.04 ,
#        152.583, 153.126, 153.669, 154.212, 154.755, 155.298, 155.841,
#        156.384, 156.927, 157.47 , 158.013, 158.556, 159.099, 159.642,
#        160.185, 160.728, 161.271, 161.814, 162.357, 162.9  , 163.443,
#        163.986, 164.529, 165.072, 165.615, 166.158, 166.701, 167.244,
#        167.787, 168.33 , 168.873, 169.416, 169.959, 170.502, 171.045,
#        171.588, 172.131, 172.674, 173.217, 173.76 , 174.303, 174.846,
#        175.389, 175.932, 176.475, 177.018, 177.561, 178.104, 178.647,
#        179.19 , 179.733, 180.276, 180.819, 181.362, 181.905, 182.448,
#        182.991, 183.534, 184.077, 184.62 , 185.163, 185.706, 186.249,
#        186.792, 187.335, 187.878, 188.421, 188.964, 189.507, 190.05 ,
#        190.593, 191.136, 191.679, 192.222, 192.765, 193.308, 193.851,
#        194.394, 194.937, 195.48 , 196.023, 196.566, 197.109, 197.652,
#        198.195, 198.738, 199.281, 199.824, 200.367, 200.91 , 201.453,
#        201.996, 202.539, 203.082, 203.625, 204.168, 204.711, 205.254,
#        205.797, 206.34 , 206.883, 207.426, 207.969, 208.512, 209.055,
#        209.598, 210.141, 210.684, 211.227, 211.77 , 212.313, 212.856,
#        213.399, 213.942, 214.485, 215.028, 215.571, 216.114, 216.657])

# %%
sig_yy =new_mat[12]
sig_yy
# Out:
# array([15.4492787 , 10.92153888,  8.10149481,  6.81255219,  6.00620354,
#         5.43707853,  5.04412647,  4.71806343,  4.45182517,  4.25042822,
#         4.0517263 ,  3.88892151,  3.78714396,  3.67683629,  3.56238926,
#         3.43692842,  3.42186814,  3.42392565,  3.40730081,  3.40171031,
#         3.38171129,  3.39771426,  3.39166392,  3.38724161,  3.37873438,
#         3.37477325,  3.36961507,  3.36604498,  3.35961611,  3.35636649,
#         3.35446954,  3.35343092,  3.32861659,  3.34420832,  3.33172218,
#         3.30469289,  3.31336111,  3.3035068 ,  3.29508253,  3.29544464,
#         3.27908919,  3.25686234,  3.23158842,  3.19686322,  3.19949793,
#         3.19161904,  3.18805444,  3.19763114,  3.17516609,  3.16062889,
#         3.15809801,  3.1511278 ,  3.13185176,  3.1212627 ,  3.1120886 ,
#         3.11024462,  3.09331747,  3.08698812,  3.06601223,  3.0581265 ,
#         3.0425451 ,  3.02915431,  3.01955772,  3.01616708,  2.97792643,
#         2.99184254,  2.97945067,  2.95158462,  2.9250931 ,  2.93490734,
#         2.9167307 ,  2.87998884,  2.86678221,  2.83695099,  2.81799704,
#         2.79921504,  2.78869549,  2.7700388 ,  2.74625189,  2.73228241,
#         2.7272635 ,  2.72520528,  2.71358049,  2.69871142,  2.69620213,
#         2.69471668,  2.69414969,  2.68873382,  2.68636239,  2.68192301,
#         2.68137985,  2.68119039,  2.67747263,  2.67593684,  2.6750979 ,
#         2.67367114,  2.67304447,  2.67296529,  2.66994676,  2.6671756 ,
#         2.66555625,  2.66171292,  2.65825255,  2.65802912,  2.65725088,
#         2.65464586,  2.65543644,  2.6513407 ,  2.65036132,  2.65053049,
#         2.64775066,  2.64685491,  2.64020773,  2.6364685 ,  2.63442522,
#         2.63419331,  2.6302022 ,  2.63106936,  2.62749409,  2.62823034,
#         2.62317089,  2.62399722,  2.61873894,  2.61697907,  2.61238294,
#         2.60958739,  2.60213519,  2.59634363,  2.59565658,  2.59232628,
#         2.58788604,  2.5827516 ,  2.57691374])

# %%
fig,ax = plt.subplots(figsize=(15,9),facecolor = 'white')
#plt.subplot(1,2,1)
plotss = plt.plot(pos_x,sig_yy,'--ko', linewidth=1, label = "$\sigma_{yy}$ curve obtained from MD")
plt.xlabel('X co-ordinate of atom position (nm)')
plt.ylabel('$\sigma_{yy}$ (GPa)')
#plt.xlim([0.66,0.75])
#plt.ylim([0, 13])
plt.rc('axes', titlesize=18) 
plt.rc('xtick', labelsize=18) 
plt.rc('ytick', labelsize=18) 
plt.rc('axes', labelsize=18)

#ax.legend()
plt.legend(loc=1, prop={'size': 18})
plt.legend(loc=1, prop={'size': 18})
plt.title('')
#grids
plt.minorticks_on()
#plt.grid (which='minor', color='g', ls='-.', lw=0.5)
#plt.grid(which='major',color='g', ls='--', lw=0.5)
#################for zooming particular range


#plt.show()
plt.savefig('mid_85_s_local.pdf',dpi = 1200)

# %%
boundary_stress = 1.447642766
total_width = 217.2

# %%
normalized_stress = sig_yy/boundary_stress
normalized_x = pos_x/total_width

# %%
fig,ax = plt.subplots(figsize=(15,9),facecolor = 'white')
#plt.subplot(1,2,1)
plotss = plt.plot(normalized_x,normalized_stress,'--ko', linewidth=1, label = "normalized data for edge crack")
plt.xlabel('$x/W$')
plt.ylabel('$\sigma_{yy}/\sigma_{yy(boundary)}$')
#plt.xlim([0.66,0.75])
#plt.ylim([0, 13])
plt.rc('axes', titlesize=18) 
plt.rc('xtick', labelsize=18) 
plt.rc('ytick', labelsize=18) 
plt.rc('axes', labelsize=18)

#ax.legend()
plt.legend(loc=1, prop={'size': 18})
plt.legend(loc=1, prop={'size': 18})
plt.title('')
#grids
plt.minorticks_on()
#plt.grid (which='minor', color='g', ls='-.', lw=0.5)
#plt.grid(which='major',color='g', ls='--', lw=0.5)
#################for zooming particular range


#plt.show()
plt.savefig('mid_85_s_local_normalized.pdf',dpi = 1200)

# %%
xx = pos_x-(2*total_width/3)
xx
# Out:
# array([ 0.181,  0.724,  1.267,  1.81 ,  2.353,  2.896,  3.439,  3.982,
#         4.525,  5.068,  5.611,  6.154,  6.697,  7.24 ,  7.783,  8.326,
#         8.869,  9.412,  9.955, 10.498, 11.041, 11.584, 12.127, 12.67 ,
#        13.213, 13.756, 14.299, 14.842, 15.385, 15.928, 16.471, 17.014,
#        17.557, 18.1  , 18.643, 19.186, 19.729, 20.272, 20.815, 21.358,
#        21.901, 22.444, 22.987, 23.53 , 24.073, 24.616, 25.159, 25.702,
#        26.245, 26.788, 27.331, 27.874, 28.417, 28.96 , 29.503, 30.046,
#        30.589, 31.132, 31.675, 32.218, 32.761, 33.304, 33.847, 34.39 ,
#        34.933, 35.476, 36.019, 36.562, 37.105, 37.648, 38.191, 38.734,
#        39.277, 39.82 , 40.363, 40.906, 41.449, 41.992, 42.535, 43.078,
#        43.621, 44.164, 44.707, 45.25 , 45.793, 46.336, 46.879, 47.422,
#        47.965, 48.508, 49.051, 49.594, 50.137, 50.68 , 51.223, 51.766,
#        52.309, 52.852, 53.395, 53.938, 54.481, 55.024, 55.567, 56.11 ,
#        56.653, 57.196, 57.739, 58.282, 58.825, 59.368, 59.911, 60.454,
#        60.997, 61.54 , 62.083, 62.626, 63.169, 63.712, 64.255, 64.798,
#        65.341, 65.884, 66.427, 66.97 , 67.513, 68.056, 68.599, 69.142,
#        69.685, 70.228, 70.771, 71.314, 71.857])

# %%
stresses_mpa = sig_yy*1000
xx_m = xx*10**(-9)
stresses_mpa
# Out:
# array([15449.27870439, 10921.53887865,  8101.49480816,  6812.55218743,
#         6006.20354191,  5437.07852622,  5044.12647489,  4718.06343101,
#         4451.82516532,  4250.42822447,  4051.72629768,  3888.92151231,
#         3787.14396266,  3676.83629082,  3562.38926141,  3436.92841582,
#         3421.8681388 ,  3423.92565494,  3407.30081409,  3401.71030725,
#         3381.71129318,  3397.71425679,  3391.66391591,  3387.24161187,
#         3378.73438308,  3374.77325146,  3369.61507104,  3366.04497791,
#         3359.61610713,  3356.36649055,  3354.46954105,  3353.43091502,
#         3328.61658823,  3344.20832297,  3331.72217513,  3304.69288769,
#         3313.36110829,  3303.50679787,  3295.08253015,  3295.44463555,
#         3279.08919479,  3256.86234321,  3231.5884232 ,  3196.86321812,
#         3199.49792869,  3191.61903737,  3188.05443686,  3197.63114288,
#         3175.16609086,  3160.62888598,  3158.09801374,  3151.12780232,
#         3131.85176245,  3121.26270383,  3112.08859949,  3110.24461967,
#         3093.31746629,  3086.98812073,  3066.01222514,  3058.12649755,
#         3042.54509664,  3029.15430795,  3019.55772089,  3016.16708037,
#         2977.92642854,  2991.84253844,  2979.45067291,  2951.58461939,
#         2925.09310105,  2934.90733558,  2916.73069987,  2879.98884148,
#         2866.78220746,  2836.95098739,  2817.99704036,  2799.21503965,
#         2788.69549451,  2770.03879729,  2746.25188753,  2732.2824059 ,
#         2727.26350273,  2725.20527854,  2713.58048951,  2698.71142366,
#         2696.20213013,  2694.71668394,  2694.14969451,  2688.73382327,
#         2686.36239107,  2681.92301147,  2681.37985499,  2681.19039494,
#         2677.47263149,  2675.93683993,  2675.0978977 ,  2673.67113582,
#         2673.04447235,  2672.96529435,  2669.94675554,  2667.17559895,
#         2665.55625477,  2661.71291818,  2658.25255358,  2658.02911699,
#         2657.2508751 ,  2654.64585814,  2655.43643722,  2651.34069586,
#         2650.36131531,  2650.53048514,  2647.75066204,  2646.85490768,
#         2640.20772795,  2636.46849747,  2634.42522489,  2634.19331483,
#         2630.20219738,  2631.06936259,  2627.49408986,  2628.23034397,
#         2623.17089053,  2623.99722332,  2618.73894019,  2616.97906786,
#         2612.38293816,  2609.5873877 ,  2602.13518709,  2596.34362507,
#         2595.65658102,  2592.32627624,  2587.88604269,  2582.75160457,
#         2576.91374161])

# %%
Y_inv = np.sqrt(2*np.pi*xx_m)
YY = 1/Y_inv
YY
# Out:
# array([29653.14617129, 14826.57308564, 11207.8357657 ,  9377.14816912,
#         8224.30299995,  7413.28654282,  6802.89829046,  6322.07200592,
#         5930.62923426,  5603.91788285,  5325.86227414,  5085.4726134 ,
#         4874.94720098,  4688.57408456,  4522.06239699,  4372.11787764,
#         4236.16373876,  4112.15149998,  3998.42941406,  3893.64884682,
#         3796.69631597,  3706.64327141,  3622.70839116,  3544.22886607,
#         3470.63824586,  3401.44914523,  3336.23959817,  3274.64218462,
#         3216.33528735,  3161.03600296,  3108.49434925,  3058.48849795,
#         3010.82082492,  2965.31461713,  2921.81131123,  2880.16816506,
#         2840.25628424,  2801.95894142,  2765.17013842,  2729.79337061,
#         2695.74056103,  2662.93113707,  2631.29122798,  2600.75296472,
#         2571.25386729,  2542.7363067 ,  2515.14703127,  2488.43674818,
#         2462.55975297,  2437.47360049,  2413.13881204,  2389.51861404,
#         2366.57870425,  2344.28704228,  2322.61366137,  2301.53049897,
#         2281.01124395,  2261.03119849,  2241.56715314,  2222.59727338,
#         2204.10099669,  2186.05893882,  2168.45280837,  2151.26532883,
#         2134.48016733,  2118.08186938,  2102.05579902,  2086.38808396,
#         2071.06556509,  2056.07574999,  2041.40677015,  2027.04734147,
#         2012.98672776,  1999.21470703,  1985.7215402 ,  1972.49794223,
#         1959.5350552 ,  1946.82442341,  1934.35797019,  1922.12797633,
#         1910.12705999,  1898.34815798,  1886.78450831,  1875.42963382,
#         1864.27732701,  1853.32163571,  1842.55684977,  1831.97748854,
#         1821.57828918,  1811.35419558,  1801.30034811,  1791.41207388,
#         1781.68487761,  1772.11443303,  1762.69657486,  1753.42729112,
#         1744.30271596,  1735.31912293,  1726.47291855,  1717.76063628,
#         1709.17893079,  1700.72457261,  1692.39444299,  1684.18552906,
#         1676.09491928,  1668.11979909,  1660.25744676,  1652.50522956,
#         1644.86059999,  1637.32109231,  1629.88431915,  1622.5479684 ,
#         1615.3098001 ,  1608.16764368,  1601.1193951 ,  1594.16301436,
#         1587.29652294,  1580.51800148,  1573.8255875 ,  1567.21747327,
#         1560.69190375,  1554.24717462,  1547.88163044,  1541.59366282,
#         1535.38170875,  1529.24424897,  1523.17980638,  1517.18694456,
#         1511.26426635,  1505.41041246,  1499.62406018,  1493.90392213,
#         1488.24874503])

# %%
#remove the entry of the first atom
YY = YY[1:]
stresses_mpa = stresses_mpa[1:]

# %%
fig,ax = plt.subplots(figsize=(15,9),facecolor = 'white')
#plt.subplot(1,2,1)
plotss = plt.plot(YY,stresses_mpa,'--ko', linewidth=1, label = "normalized data for edge crack")
plt.xlabel('$x/W$')
plt.ylabel('$\sigma_{yy}/\sigma_{yy(boundary)}$')
#plt.xlim([0.66,0.75])
#plt.ylim([0, 13])
plt.rc('axes', titlesize=18) 
plt.rc('xtick', labelsize=18) 
plt.rc('ytick', labelsize=18) 
plt.rc('axes', labelsize=18)

#ax.legend()
plt.legend(loc=1, prop={'size': 18})
plt.legend(loc=1, prop={'size': 18})
plt.title('')
#grids
plt.minorticks_on()
#plt.grid (which='minor', color='g', ls='-.', lw=0.5)
#plt.grid(which='major',color='g', ls='--', lw=0.5)
#################for zooming particular range


plt.show()
#plt.savefig('edge_s_local_normalized.pdf',dpi = 1200)

# %%
ss_cut =stresses_mpa[4:5]
y_cut = YY[4:5]

# %%
m_x = np.mean(y_cut)
m_y = np.mean(ss_cut)
kic = m_y/m_x
kic
# Out:
# 0.7334234950738251

# %%
b_0 = 0     
b_1 = 0.731941576161792

# %%
stress_fit = b_1 * y_cut + b_0 
error = ss_cut - stress_fit
n_1 = np.size(y_cut)
ss_mean = np.mean(ss_cut)
se = np.sum(error**2)
print('squared error is', se)
mse = se/n_1 
print('mean squared error is', mse)
SSt = np.sum((ss_cut - ss_mean)**2)
R2 = 1- (se/SSt)
print('R square is', R2)
# Out:
# squared error is 25723.961675510327
# mean squared error is 4287.3269459183875
# R square is 0.996763514287854

# %%
for i in range(2,10):
    print(i+1)
    ss_cut =stresses_mpa[0:i]
    y_cut = YY[0:i]

    m_x = np.mean(y_cut)
    m_y = np.mean(ss_cut)
    kic = m_y/m_x
    print(kic)

    b_0 = 0     
    b_1 = kic

    stress_fit = b_1 * y_cut + b_0 
    error = ss_cut - stress_fit
    n_1 = np.size(y_cut)
    ss_mean = np.mean(ss_cut)
    se = np.sum(error**2)
    print('squared error is', se)
    mse = se/n_1 
    print('mean squared error is', mse)
    SSt = np.sum((ss_cut - ss_mean)**2)
    R2 = 1- (se/SSt)
    print('R square is', R2)
# Out:
# 3
# 0.7306881364367365
# squared error is 15466.120710977539
# mean squared error is 7733.060355488769
# R square is 0.9961104478350191
# 4
# 0.7295806241822527
# squared error is 17426.07536164221
# mean squared error is 5808.69178721407
# R square is 0.9980270724600789
# 5
# 0.7297160959189505
# squared error is 17340.420243271776
# mean squared error is 4335.105060817944
# R square is 0.9987546996916215
# 6
# 0.7302544793026895
# squared error is 17594.815269163508
# mean squared error is 3518.9630538327015
# R square is 0.9990748628386099
# 7
# 0.7315730070442535
# squared error is 22259.728262787517
# mean squared error is 3709.9547104645862
# R square is 0.9990672765396514
# 8
# 0.7330222860907097
# squared error is 30437.265825152776
# mean squared error is 4348.180832164682
# R square is 0.9989335867497167
# 9
# 0.734513508467133
# squared error is 41925.14306883223
# mean squared error is 5240.642883604029
# R square is 0.9987312273334958
# 10
# 0.7362870814259612
# squared error is 61971.6011197022
# mean squared error is 6885.733457744689
# R square is 0.9983382157446445

# %%
fig,ax = plt.subplots(figsize=(15,9),facecolor = 'white')
#plt.subplot(1,2,1)
plotss = plt.plot(y_cut,ss_cut,'ko', linewidth=1, label = "data points")
plotss = plt.plot(y_cut,stress_fit,'-k', linewidth=1, label = "linear fit")
plt.xlabel('$x/W$')
plt.ylabel('$\sigma_{yy}/\sigma_{yy(boundary)}$')
#plt.xlim([0.66,0.75])
#plt.ylim([0, 13])
plt.rc('axes', titlesize=18) 
plt.rc('xtick', labelsize=18) 
plt.rc('ytick', labelsize=18) 
plt.rc('axes', labelsize=18)

#ax.legend()
plt.legend(loc=2, prop={'size': 18})
plt.legend(loc=2, prop={'size': 18})
plt.title('')
#grids
plt.minorticks_on()
#plt.grid (which='minor', color='g', ls='-.', lw=0.5)
#plt.grid(which='major',color='g', ls='--', lw=0.5)
#################for zooming particular range


plt.show()

# %%
array = [pos_x,sig_yy,normalized_x,normalized_stress]

df = pd.DataFrame(array).T
df.to_excel(excel_writer = "nd_0.85.xlsx")
