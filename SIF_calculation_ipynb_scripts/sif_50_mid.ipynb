# %%
import matplotlib as mpl
mpl.rcParams['font.family']='serif'
mpl.rcParams['mathtext.fontset']='cm'
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
dt = pd.read_excel (r'stress_data_50.xlsx')
mat = dt.to_numpy()
new_mat=np.transpose(mat)

# %%
pos_x = new_mat[1]
pos_x = pos_x/10
pos_x
# Out:
# array([144.981, 145.524, 146.067, 146.61 , 147.153, 147.696, 148.239,
#        148.782, 149.325, 149.868, 150.411, 150.954, 151.497, 152.04 ,
#        152.583, 153.126, 153.669, 154.212, 154.755, 155.298, 155.841,
#        156.384, 156.927, 157.47 , 158.013, 158.556, 159.099, 159.642,
#        160.185, 160.728, 161.271, 161.814, 162.357, 162.9  , 163.443,
#        163.986, 164.529, 165.072, 165.615, 166.158, 166.701, 167.244,
#        167.787, 168.33 , 168.873, 169.416, 169.959, 170.502, 171.045,
#        171.588, 172.131, 172.674, 173.217, 173.76 , 174.303, 174.846,
#        175.389, 175.932, 176.475, 177.018, 177.561, 178.104, 178.647,
#        179.19 , 179.733, 180.276, 180.819, 181.362, 181.905, 182.448,
#        182.991, 183.534, 184.077, 184.62 , 185.163, 185.706, 186.249,
#        186.792, 187.335, 187.878, 188.421, 188.964, 189.507, 190.05 ,
#        190.593, 191.136, 191.679, 192.222, 192.765, 193.308, 193.851,
#        194.394, 194.937, 195.48 , 196.023, 196.566, 197.109, 197.652,
#        198.195, 198.738, 199.281, 199.824, 200.367, 200.91 , 201.453,
#        201.996, 202.539, 203.082, 203.625, 204.168, 204.711, 205.254,
#        205.797, 206.34 , 206.883, 207.426, 207.969, 208.512, 209.055,
#        209.598, 210.141, 210.684, 211.227, 211.77 , 212.313, 212.856,
#        213.399, 213.942, 214.485, 215.028, 215.571, 216.114, 216.657])

# %%
sig_yy =new_mat[11]
sig_yy
# Out:
# array([23.21993664, 21.48029674, 14.84178488, 12.04605066, 10.51633503,
#         9.50480411,  8.71108314,  8.21312507,  7.71993617,  7.40329735,
#         6.94076527,  6.80788433,  6.59979763,  6.31791344,  6.22845716,
#         6.04070689,  5.83312477,  5.76428337,  5.65950264,  5.61458551,
#         5.51152394,  5.45068828,  5.33018271,  5.19687624,  5.09013258,
#         5.10862427,  5.01547594,  4.98740631,  4.84854141,  4.81548566,
#         4.8332599 ,  4.84335324,  4.76364835,  4.69222201,  4.69828695,
#         4.54853468,  4.54170742,  4.60757644,  4.52556051,  4.56284059,
#         4.45238532,  4.41792981,  4.33390905,  4.41554939,  4.34464359,
#         4.32889474,  4.40671081,  4.41784009,  4.32463714,  4.26862249,
#         4.23896035,  4.23909398,  4.31897171,  4.23359971,  4.20678353,
#         4.18341324,  4.1257123 ,  4.17620306,  4.18341561,  4.13158876,
#         4.05730272,  4.02755863,  4.03175842,  4.04968828,  3.99989469,
#         4.01753639,  4.03179044,  4.01503678,  4.04046647,  3.8764829 ,
#         4.08272149,  3.92156263,  4.0423515 ,  3.94419976,  3.8447452 ,
#         3.95240727,  3.9247287 ,  3.84038105,  3.91755724,  3.80281598,
#         3.89458814,  3.82414653,  3.89906191,  3.85310407,  3.87015678,
#         3.81852946,  3.87631793,  3.79741879,  3.81061415,  3.8021814 ,
#         3.82434238,  3.77717119,  3.74321832,  3.79500992,  3.77864917,
#         3.69589074,  3.6247418 ,  3.67519474,  3.7095971 ,  3.72207489,
#         3.72522106,  3.66901742,  3.72430813,  3.59264065,  3.65003144,
#         3.70799615,  3.55102174,  3.60201679,  3.67103558,  3.65334611,
#         3.61102819,  3.56501881,  3.62231561,  3.63881803,  3.64304354,
#         3.57979892,  3.52177855,  3.5439338 ,  3.53578219,  3.5550806 ,
#         3.54693606,  3.48028727,  3.51495063,  3.52757457,  3.43164931,
#         3.48570367,  3.42023814,  3.44426462,  3.47084471,  3.3924393 ,
#         3.39392891,  3.37269088,  3.31048527])

# %%
fig,ax = plt.subplots(figsize=(15,9),facecolor = 'white')
#plt.subplot(1,2,1)
plotss = plt.plot(pos_x,sig_yy,'--ko', linewidth=1, label = "$\sigma_{yy}$ curve obtained from MD")
plt.xlabel('X co-ordinate of atom position (nm)')
plt.ylabel('$\sigma_{yy}$ (GPa)')
#plt.xlim([0.66,0.75])
#plt.ylim([0, 13])
plt.rc('axes', titlesize=18) 
plt.rc('xtick', labelsize=18) 
plt.rc('ytick', labelsize=18) 
plt.rc('axes', labelsize=18)

#ax.legend()
plt.legend(loc=1, prop={'size': 18})
plt.legend(loc=1, prop={'size': 18})
plt.title('')
#grids
plt.minorticks_on()
#plt.grid (which='minor', color='g', ls='-.', lw=0.5)
#plt.grid(which='major',color='g', ls='--', lw=0.5)
#################for zooming particular range


#plt.show()
plt.savefig('mid_50_s_local.pdf',dpi = 1200)

# %%
boundary_stress = 3.298572469
total_width = 217.2

# %%
normalized_stress = sig_yy/boundary_stress
normalized_x = pos_x/total_width
normalized_x
# Out:
# array([0.6675, 0.67  , 0.6725, 0.675 , 0.6775, 0.68  , 0.6825, 0.685 ,
#        0.6875, 0.69  , 0.6925, 0.695 , 0.6975, 0.7   , 0.7025, 0.705 ,
#        0.7075, 0.71  , 0.7125, 0.715 , 0.7175, 0.72  , 0.7225, 0.725 ,
#        0.7275, 0.73  , 0.7325, 0.735 , 0.7375, 0.74  , 0.7425, 0.745 ,
#        0.7475, 0.75  , 0.7525, 0.755 , 0.7575, 0.76  , 0.7625, 0.765 ,
#        0.7675, 0.77  , 0.7725, 0.775 , 0.7775, 0.78  , 0.7825, 0.785 ,
#        0.7875, 0.79  , 0.7925, 0.795 , 0.7975, 0.8   , 0.8025, 0.805 ,
#        0.8075, 0.81  , 0.8125, 0.815 , 0.8175, 0.82  , 0.8225, 0.825 ,
#        0.8275, 0.83  , 0.8325, 0.835 , 0.8375, 0.84  , 0.8425, 0.845 ,
#        0.8475, 0.85  , 0.8525, 0.855 , 0.8575, 0.86  , 0.8625, 0.865 ,
#        0.8675, 0.87  , 0.8725, 0.875 , 0.8775, 0.88  , 0.8825, 0.885 ,
#        0.8875, 0.89  , 0.8925, 0.895 , 0.8975, 0.9   , 0.9025, 0.905 ,
#        0.9075, 0.91  , 0.9125, 0.915 , 0.9175, 0.92  , 0.9225, 0.925 ,
#        0.9275, 0.93  , 0.9325, 0.935 , 0.9375, 0.94  , 0.9425, 0.945 ,
#        0.9475, 0.95  , 0.9525, 0.955 , 0.9575, 0.96  , 0.9625, 0.965 ,
#        0.9675, 0.97  , 0.9725, 0.975 , 0.9775, 0.98  , 0.9825, 0.985 ,
#        0.9875, 0.99  , 0.9925, 0.995 , 0.9975])

# %%
fig,ax = plt.subplots(figsize=(15,9),facecolor = 'white')
#plt.subplot(1,2,1)
plotss = plt.plot(normalized_x,normalized_stress,'--ko', linewidth=1, label = "normalized data for edge crack")
plt.xlabel('$x/W$')
plt.ylabel('$\sigma_{yy}/\sigma_{yy(boundary)}$')
#plt.xlim([0.66,0.75])
#plt.ylim([0, 13])
plt.rc('axes', titlesize=18) 
plt.rc('xtick', labelsize=18) 
plt.rc('ytick', labelsize=18) 
plt.rc('axes', labelsize=18)

#ax.legend()
plt.legend(loc=1, prop={'size': 18})
plt.legend(loc=1, prop={'size': 18})
plt.title('')
#grids
plt.minorticks_on()
#plt.grid (which='minor', color='g', ls='-.', lw=0.5)
#plt.grid(which='major',color='g', ls='--', lw=0.5)
#################for zooming particular range
#          1535.38170875,  1529.24424897,  1523.17980638,  1517.18694456,
#          1511.26426635,  1505.41041246,  1499.62406018,  1493.90392213,
#          1488.24874503]),
#  array([ 0.181,  0.724,  1.267,  1.81 ,  2.353,  2.896,  3.439,  3.982,
#          4.525,  5.068,  5.611,  6.154,  6.697,  7.24 ,  7.783,  8.326,
#          8.869,  9.412,  9.955, 10.498, 11.041, 11.584, 12.127, 12.67 ,
#         13.213, 13.756, 14.299, 14.842, 15.385, 15.928, 16.471, 17.014,
#         17.557, 18.1  , 18.643, 19.186, 19.729, 20.272, 20.815, 21.358,
#         21.901, 22.444, 22.987, 23.53 , 24.073, 24.616, 25.159, 25.702,
#         26.245, 26.788, 27.331, 27.874, 28.417, 28.96 , 29.503, 30.046,
#         30.589, 31.132, 31.675, 32.218, 32.761, 33.304, 33.847, 34.39 ,
#         34.933, 35.476, 36.019, 36.562, 37.105, 37.648, 38.191, 38.734,
#         39.277, 39.82 , 40.363, 40.906, 41.449, 41.992, 42.535, 43.078,
#         43.621, 44.164, 44.707, 45.25 , 45.793, 46.336, 46.879, 47.422,
#         47.965, 48.508, 49.051, 49.594, 50.137, 50.68 , 51.223, 51.766,
#         52.309, 52.852, 53.395, 53.938, 54.481, 55.024, 55.567, 56.11 ,
#         56.653, 57.196, 57.739, 58.282, 58.825, 59.368, 59.911, 60.454,
#         60.997, 61.54 , 62.083, 62.626, 63.169, 63.712, 64.255, 64.798,
#         65.341, 65.884, 66.427, 66.97 , 67.513, 68.056, 68.599, 69.142,
#         69.685, 70.228, 70.771, 71.314, 71.857]))

# %%
#remove the entry of the first atom
YY = YY[1:]
stresses_mpa = stresses_mpa[1:]

# %%
fig,ax = plt.subplots(figsize=(15,9),facecolor = 'white')
#plt.subplot(1,2,1)
plotss = plt.plot(YY,stresses_mpa,'--ko', linewidth=1, label = "normalized data for edge crack")
plt.xlabel('$x/W$')
plt.ylabel('$\sigma_{yy}/\sigma_{yy(boundary)}$')
#plt.xlim([0.66,0.75])
#plt.ylim([0, 13])
plt.rc('axes', titlesize=18) 
plt.rc('xtick', labelsize=18) 
plt.rc('ytick', labelsize=18) 
plt.rc('axes', labelsize=18)

#ax.legend()
plt.legend(loc=1, prop={'size': 18})
plt.legend(loc=1, prop={'size': 18})
plt.title('')
#grids
plt.minorticks_on()
#plt.grid (which='minor', color='g', ls='-.', lw=0.5)
#plt.grid(which='major',color='g', ls='--', lw=0.5)
#################for zooming particular range


plt.show()
#plt.savefig('edge_s_local_normalized.pdf',dpi = 1200)

# %%
ss_cut =stresses_mpa[1:10]
y_cut = YY[1:10]

# %%
m_x = np.mean(y_cut)
m_y = np.mean(ss_cut)
kic = m_y/m_x
kic
# Out:
# 1.2973846431007177

# %%
b_0 = 0     
b_1 = 1.3036551775730072

# %%
stress_fit = b_1 * y_cut + b_0 
error = ss_cut - stress_fit
n_1 = np.size(y_cut)
ss_mean = np.mean(ss_cut)
se = np.sum(error**2)
print('squared error is', se)
mse = se/n_1 
print('mean squared error is', mse)
SSt = np.sum((ss_cut - ss_mean)**2)
R2 = 1- (se/SSt)
print('R square is', R2)
# Out:
# squared error is 188009.67387489896
# mean squared error is 20889.963763877662
# R square is 0.9964137661234673

# %%
fig,ax = plt.subplots(figsize=(15,9),facecolor = 'white')
#plt.subplot(1,2,1)
plotss = plt.plot(y_cut,ss_cut,'ko', linewidth=1, label = "data points")
plotss = plt.plot(y_cut,stress_fit,'-k', linewidth=1, label = "linear fit")
plt.xlabel('$x/W$')
plt.ylabel('$\sigma_{yy}/\sigma_{yy(boundary)}$')
#plt.xlim([0.66,0.75])
#plt.ylim([0, 13])
plt.rc('axes', titlesize=18) 
plt.rc('xtick', labelsize=18) 
plt.rc('ytick', labelsize=18) 
plt.rc('axes', labelsize=18)

#ax.legend()
plt.legend(loc=2, prop={'size': 18})
plt.legend(loc=2, prop={'size': 18})
plt.title('')
#grids
plt.minorticks_on()
#plt.grid (which='minor', color='g', ls='-.', lw=0.5)
#plt.grid(which='major',color='g', ls='--', lw=0.5)
#################for zooming particular range


plt.show()

# %%
array = [pos_x,sig_yy,normalized_x,normalized_stress]

df = pd.DataFrame(array).T
df.to_excel(excel_writer = "nd_0.50.xlsx")

# %%
array_new = [y_cut,ss_cut,stress_fit]

df = pd.DataFrame(array_new).T
df.to_excel(excel_writer = "new_50.xlsx")
